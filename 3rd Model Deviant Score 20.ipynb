# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd
import spacy

import matplotlib.pyplot as plt
import seaborn as sns

sns.set
# %matplotlib inline

# %% [markdown]
# # Load the dataset

# %%
imdb_data=pd.read_csv('IMDBDataset.csv')

df_train=imdb_data[:2000]

print("Head")
print(df_train.head())
print("_____________________________________________________________________________")
print("Shape")
print(df_train.shape)
print("_____________________________________________________________________________")
print(df_train.info())

df_train['sentiment'].value_counts().plot(kind='bar');
df_train.describe()
# Out:
# Head
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# _____________________________________________________________________________
# Shape
# (2000, 2)
# _____________________________________________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
# review       2000 non-null object
# sentiment    2000 non-null object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None
#                                                    review sentiment
# count                                                2000      2000
# unique                                               2000         2
# top     Perfect movies are rare. Even my favorite film...  positive
# freq                                                    1      1005

# %% [markdown]
# The data is clean, there is no Naan values

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Tokenizing

# %% [markdown]
# Creation of a tokenize's function permitting to automatically tokenize our train and test set

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

def tokenize(data):
    corpus = [word_tokenize(token) for token in data]
    lowercase_train = [[token.lower() for token in doc] for doc in corpus]
    alphas = [[token for token in doc if token.isalpha()] for doc in lowercase_train]
    stop_words = stopwords.words('english')
    train_no_stop = [[token for token in doc if token not in stop_words] for doc in alphas]
    stemmer = PorterStemmer()
    stemmed = [[stemmer.stem(token) for token in doc] for doc in train_no_stop]
    train_clean_str = [ ' '.join(doc) for doc in stemmed]
    return train_clean_str

# %%
X_train=imdb_data.review[:2000]
y_train=imdb_data.sentiment[:2000]

X_train = tokenize(X_train)

X_test2=imdb_data.review[40000:45000]
y_test2=imdb_data.sentiment[40000:45000]

X_test2 = tokenize(X_test2)
y_test2 = y_test2.values.tolist()

X_train[1]
# Out:
# 'wonder littl product br br film techniqu fashion give comfort sometim discomfort sens realism entir piec br br actor extrem well michael sheen got polari voic pat truli see seamless edit guid refer william diari entri well worth watch terrificli written perform piec master product one great master comedi life br br realism realli come home littl thing fantasi guard rather use tradit techniqu remain solid disappear play knowledg sens particularli scene concern orton halliwel set particularli flat halliwel mural decor everi surfac terribl well done'

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.feature_extraction.text import CountVectorizer

cvec = CountVectorizer(stop_words='english')

# %% [markdown]
# ## Machine learning models

# %% [markdown]
# ### MultinomialNB

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB()
pipe = Pipeline([('vectorizer', cvec), ('mnb', mnb)])

y_train=y_train.values.tolist()
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report


cm = confusion_matrix(y_train, y_pred)
accuracy = accuracy_score(y_pred, y_train)

print(cm)
print("Accuracy :" , accuracy)

cv = cross_val_score(pipe, X_train, y_train, scoring='f1_macro', cv=5, ).mean()

cr = classification_report(y_train, y_pred)
print(cr, cv)
# Out:
# [[990   5]
#  [ 59 946]]
# Accuracy : 0.968
#               precision    recall  f1-score   support
#
#     negative       0.94      0.99      0.97       995
#     positive       0.99      0.94      0.97      1005
#
#    micro avg       0.97      0.97      0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#  0.809793093779436

# %% [markdown]
# # Semi Supervised

# %%
iterasi=1
acc_train=[]
acc_test=[]
acc_test2=[]

seed=1.10
data_total=len(X_train)
data_iter=int(seed*data_total)

# %%
print(data_total)
print(data_iter)


y_pred_fromtrain=pipe.predict(X_train)
cv = cross_val_score(pipe, X_train, y_train, scoring='f1_macro', cv=5, ).mean()
cr = classification_report(y_pred_fromtrain, y_train)
cm = confusion_matrix(y_train, y_pred_fromtrain)
accuracy = accuracy_score(y_pred_fromtrain, y_train)
acc_train.append(accuracy)
print("\nTrain Data=",len(X_train),len(y_train))
print("Predicton from train data model ke-",iterasi)
print("\nCross validation score:",cv,"\n",cr)
print("\nConfusion Matrix : \n",cm)
print("Accuracy :" , accuracy)
print("__________________________________________________________________________________________________")


X_test=imdb_data.review[data_total:data_iter]
y_test=imdb_data.sentiment[data_total:data_iter]

pipe.fit(X_train,y_train)

print("Train Data=",len(X_train),len(y_train))
print("Test Data=",len(X_test),len(y_test))

y_test=y_test.values.tolist()
X_test=tokenize(X_test)
y_pred=pipe.predict(X_test)

cr = classification_report(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_pred, y_test)
acc_test.append(accuracy)
print("prediction from test data, model ke-",iterasi)
print(cr)
print("\nConfusion Matrix : \n",cm)
print("Accuracy :" , accuracy)
print("__________________________________________________________________________________________________")

y_pred_fromtest2=pipe.predict(X_test2)
cr = classification_report(y_test2, y_pred_fromtest2)
cm = confusion_matrix(y_test2, y_pred_fromtest2)
accuracy = accuracy_score(y_pred_fromtest2, y_test2)
acc_test2.append(accuracy)
print("prediction from test data, model ke-",iterasi)
print(cr)
print("\nConfusion Matrix : \n",cm)
print("Accuracy :" , accuracy)
print("__________________________________________________________________________________________________")





iterasi=iterasi+1


prob=pipe.predict_proba(X_test)
prob_sum=[]
for data in range (0,len(prob)):
    prob_sum.append(prob[data][0]-prob[data][1])

for data in range (0,len(X_test)) :
    
    if (abs(prob_sum[data])) > 0.99 :
        X=X_test[data]
        y=y_pred[data]
        X_train.append(X)
        y_train.append(y)
        
print(len(X_train),len(y_train))

data_total=data_iter
data_iter=int(seed*data_total)
# Out:
# 2000
# 2200
#
# Train Data= 2000 2000
# Predicton from train data model ke- 1
#
# Cross validation score: 0.809793093779436
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.97      1049
#     positive       0.94      0.99      0.97       951
#
#    micro avg       0.97      0.97      0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
#
# Confusion Matrix :
#  [[990   5]
#  [ 59 946]]
# Accuracy : 0.968
# __________________________________________________________________________________________________
# Train Data= 2000 2000
# Test Data= 200 200
# prediction from test data, model ke- 1
#               precision    recall  f1-score   support
#
#     negative       0.77      0.82      0.80        88
#     positive       0.85      0.81      0.83       112
#
#    micro avg       0.81      0.81      0.81       200
#    macro avg       0.81      0.82      0.81       200
# weighted avg       0.82      0.81      0.82       200
#
#
# Confusion Matrix :
#  [[72 16]
#  [21 91]]
# Accuracy : 0.815
# __________________________________________________________________________________________________
# prediction from test data, model ke- 1
#               precision    recall  f1-score   support
#
#     negative       0.80      0.84      0.82      2463
#     positive       0.83      0.79      0.81      2537
#
#    micro avg       0.81      0.81      0.81      5000
#    macro avg       0.82      0.81      0.81      5000
# weighted avg       0.82      0.81      0.81      5000
#
#
# Confusion Matrix :
#  [[2060  403]
#  [ 525 2012]]
# Accuracy : 0.8144
# __________________________________________________________________________________________________
# 2138 2138

# %%
while data_total < 10000 :

    print(data_total,data_iter,len(X_train))


    y_pred_fromtrain=pipe.predict(X_train)
    cv = cross_val_score(pipe, X_train, y_train, scoring='f1_macro', cv=5, ).mean()
    cr = classification_report(y_pred_fromtrain, y_train)
    cm = confusion_matrix(y_train, y_pred_fromtrain)
    accuracy = accuracy_score(y_pred_fromtrain, y_train)
    acc_train.append(accuracy)
    print("\nTrain Data=",len(X_train),len(y_train))
    print("Predicton from train data model ke-",iterasi)
    print("\nCross validation score:",cv,"\n",cr)
    print("\nConfusion Matrix : \n",cm)
    print("Accuracy :" , accuracy)
    print("__________________________________________________________________________________________________")


    X_test=imdb_data.review[data_total:data_iter]
    y_test=imdb_data.sentiment[data_total:data_iter]

    pipe.fit(X_train,y_train)

    print("Train Data=",len(X_train),len(y_train))
    print("Test Data=",len(X_test),len(y_test))

    y_test=y_test.values.tolist()
    X_test=tokenize(X_test)
    y_pred=pipe.predict(X_test)

    cr = classification_report(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_pred, y_test)
    acc_test.append(accuracy)
    print("prediction from test data, model ke-",iterasi)
    print(cr)
    print("\nConfusion Matrix : \n",cm)
    print("Accuracy :" , accuracy)
    print("__________________________________________________________________________________________________")
    
    y_pred_fromtest2=pipe.predict(X_test2)
    cr = classification_report(y_test2, y_pred_fromtest2)
    cm = confusion_matrix(y_test2, y_pred_fromtest2)
    accuracy = accuracy_score(y_pred_fromtest2, y_test2)
    acc_test2.append(accuracy)
    print("prediction from test data, model ke-",iterasi)
    print(cr)
    print("\nConfusion Matrix : \n",cm)
    print("Accuracy :" , accuracy)
    print("__________________________________________________________________________________________________")





    iterasi=iterasi+1


    prob=pipe.predict_proba(X_test)
    prob_sum=[]
    for data in range (0,len(prob)):
        prob_sum.append(prob[data][0]-prob[data][1])

    for data in range (0,len(X_test)) :
         if (data_total+data) < 10000:
                if (abs(prob_sum[data])) > 0.99 :
                    X=X_test[data]
                    y=y_pred[data]
                    X_train.append(X)
                    y_train.append(y)

    print(len(X_train),len(y_train))
    
    data_total=data_iter
    data_iter=int(seed*data_total)
# Out:
# 2200 2420 2138
#
# Train Data= 2138 2138
# Predicton from train data model ke- 2
#
# Cross validation score: 0.8211243031556338
#                precision    recall  f1-score   support
#
#     negative       1.00      0.95      0.97      1117
#     positive       0.95      1.00      0.97      1021
#
#    micro avg       0.97      0.97      0.97      2138
#    macro avg       0.97      0.97      0.97      2138
# weighted avg       0.97      0.97      0.97      2138
#
#
# Confusion Matrix :
#  [[1058    5]
#  [  59 1016]]
# Accuracy : 0.9700654817586529
# __________________________________________________________________________________________________
# Train Data= 2138 2138
# Test Data= 220 220
# prediction from test data, model ke- 2
#               precision    recall  f1-score   support
#
#     negative       0.80      0.81      0.80       111
#     positive       0.80      0.79      0.80       109
#
#    micro avg       0.80      0.80      0.80       220
#    macro avg       0.80      0.80      0.80       220
# weighted avg       0.80      0.80      0.80       220
#
#
# Confusion Matrix :
#  [[90 21]
#  [23 86]]
# Accuracy : 0.8
# __________________________________________________________________________________________________
# prediction from test data, model ke- 2
#               precision    recall  f1-score   support
#
#     negative       0.79      0.84      0.81      2463
#     positive       0.83      0.78      0.81      2537
#
#    micro avg       0.81      0.81      0.81      5000
#    macro avg       0.81      0.81      0.81      5000
# weighted avg       0.81      0.81      0.81      5000
#
#
# Confusion Matrix :
#  [[2068  395]
#  [ 553 1984]]
# Accuracy : 0.8104
# __________________________________________________________________________________________________
# 2288 2288
# 2420 2662 2288
#
# Train Data= 2288 2288
# Predicton from train data model ke- 3
#
# Cross validation score: 0.8289154566215003
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.97      1203
#     positive       0.94      0.99      0.96      1085
#
#    micro avg       0.96      0.96      0.96      2288
#    macro avg       0.96      0.97      0.96      2288
# weighted avg       0.97      0.96      0.96      2288
#
#
# Confusion Matrix :
#  [[1130    8]
#  [  73 1077]]
# Accuracy : 0.9645979020979021
# __________________________________________________________________________________________________
# Train Data= 2288 2288
# Test Data= 242 242
# prediction from test data, model ke- 3
#               precision    recall  f1-score   support
#
#     negative       0.81      0.80      0.80       127
#     positive       0.78      0.80      0.79       115
#
#    micro avg       0.80      0.80      0.80       242
#    macro avg       0.80      0.80      0.80       242
# weighted avg       0.80      0.80      0.80       242
#
#
# Confusion Matrix :
#  [[101  26]
#  [ 23  92]]
# Accuracy : 0.7975206611570248
# __________________________________________________________________________________________________
# prediction from test data, model ke- 3
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81      2463
#     positive       0.83      0.79      0.81      2537
#
#    micro avg       0.81      0.81      0.81      5000
#    macro avg       0.81      0.81      0.81      5000
# weighted avg       0.81      0.81      0.81      5000
#
#
# Confusion Matrix :
#  [[2050  413]
#  [ 539 1998]]
# Accuracy : 0.8096
# __________________________________________________________________________________________________
# 2459 2459
# 2662 2928 2459
#
# Train Data= 2459 2459
# Predicton from train data model ke- 4
#
# Cross validation score: 0.8405430054086377
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.97      1304
#     positive       0.94      0.99      0.96      1155
#
#    micro avg       0.96      0.96      0.96      2459
#    macro avg       0.96      0.97      0.96      2459
# weighted avg       0.97      0.96      0.96      2459
#
#
# Confusion Matrix :
#  [[1225    9]
#  [  79 1146]]
# Accuracy : 0.964213094753965
# __________________________________________________________________________________________________
# Train Data= 2459 2459
# Test Data= 266 266
# prediction from test data, model ke- 4
#               precision    recall  f1-score   support
#
#     negative       0.84      0.86      0.85       138
#     positive       0.84      0.83      0.83       128
#
#    micro avg       0.84      0.84      0.84       266
#    macro avg       0.84      0.84      0.84       266
# weighted avg       0.84      0.84      0.84       266
#
#
# Confusion Matrix :
#  [[118  20]
#  [ 22 106]]
# Accuracy : 0.8421052631578947
# __________________________________________________________________________________________________
# prediction from test data, model ke- 4
#               precision    recall  f1-score   support
#
#     negative       0.78      0.83      0.80      2463
#     positive       0.82      0.78      0.80      2537
#
#    micro avg       0.80      0.80      0.80      5000
#    macro avg       0.80      0.80      0.80      5000
# weighted avg       0.80      0.80      0.80      5000
#
#
# Confusion Matrix :
#  [[2037  426]
#  [ 563 1974]]
# Accuracy : 0.8022
# __________________________________________________________________________________________________
# 2660 2660
# 2928 3220 2660
#
# Train Data= 2660 2660
# Predicton from train data model ke- 5
#
# Cross validation score: 0.8531173195500207
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      1425
#     positive       0.93      0.99      0.96      1235
#
#    micro avg       0.96      0.96      0.96      2660
#    macro avg       0.96      0.96      0.96      2660
# weighted avg       0.96      0.96      0.96      2660
#
#
# Confusion Matrix :
#  [[1334    9]
#  [  91 1226]]
# Accuracy : 0.9624060150375939
# __________________________________________________________________________________________________
# Train Data= 2660 2660
# Test Data= 292 292
# prediction from test data, model ke- 5
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81       142
#     positive       0.83      0.79      0.81       150
#
#    micro avg       0.81      0.81      0.81       292
#    macro avg       0.81      0.81      0.81       292
# weighted avg       0.81      0.81      0.81       292
#
#
# Confusion Matrix :
#  [[118  24]
#  [ 32 118]]
# Accuracy : 0.8082191780821918
# __________________________________________________________________________________________________
# prediction from test data, model ke- 5
#               precision    recall  f1-score   support
#
#     negative       0.78      0.83      0.81      2463
#     positive       0.83      0.77      0.80      2537
#
#    micro avg       0.80      0.80      0.80      5000
#    macro avg       0.80      0.80      0.80      5000
# weighted avg       0.80      0.80      0.80      5000
#
#
# Confusion Matrix :
#  [[2054  409]
#  [ 579 1958]]
# Accuracy : 0.8024
# __________________________________________________________________________________________________
# 2871 2871
# 3220 3542 2871
#
# Train Data= 2871 2871
# Predicton from train data model ke- 6
#
# Cross validation score: 0.8604893229048927
#                precision    recall  f1-score   support
#
#     negative       0.99      0.93      0.96      1548
#     positive       0.92      0.99      0.96      1323
#
#    micro avg       0.96      0.96      0.96      2871
#    macro avg       0.96      0.96      0.96      2871
# weighted avg       0.96      0.96      0.96      2871
#
#
# Confusion Matrix :
#  [[1442   16]
#  [ 106 1307]]
# Accuracy : 0.95750609543713
# __________________________________________________________________________________________________
# Train Data= 2871 2871
# Test Data= 322 322
# prediction from test data, model ke- 6
#               precision    recall  f1-score   support
#
#     negative       0.76      0.84      0.80       167
#     positive       0.81      0.72      0.76       155
#
#    micro avg       0.78      0.78      0.78       322
#    macro avg       0.79      0.78      0.78       322
# weighted avg       0.79      0.78      0.78       322
#
#
# Confusion Matrix :
#  [[141  26]
#  [ 44 111]]
# Accuracy : 0.782608695652174
# __________________________________________________________________________________________________
# prediction from test data, model ke- 6
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80      2463
#     positive       0.83      0.76      0.79      2537
#
#    micro avg       0.80      0.80      0.80      5000
#    macro avg       0.80      0.80      0.80      5000
# weighted avg       0.80      0.80      0.80      5000
#
#
# Confusion Matrix :
#  [[2054  409]
#  [ 604 1933]]
# Accuracy : 0.7974
# __________________________________________________________________________________________________
# 3107 3107
# 3542 3896 3107
# Train Data= 3107 3107
# Predicton from train data model ke- 7
#
# Cross validation score: 0.8716287733046155
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      1695
#     positive       0.93      0.99      0.96      1412
#
#    micro avg       0.96      0.96      0.96      3107
#    macro avg       0.96      0.96      0.96      3107
# weighted avg       0.96      0.96      0.96      3107
#
#
# Confusion Matrix :
#  [[1585   16]
#  [ 110 1396]]
# Accuracy : 0.9594464113292566
# __________________________________________________________________________________________________
# Train Data= 3107 3107
# Test Data= 354 354
# prediction from test data, model ke- 7
#               precision    recall  f1-score   support
#
#     negative       0.81      0.85      0.83       191
#     positive       0.81      0.76      0.78       163
#
#    micro avg       0.81      0.81      0.81       354
#    macro avg       0.81      0.80      0.81       354
# weighted avg       0.81      0.81      0.81       354
#
#
# Confusion Matrix :
#  [[162  29]
#  [ 39 124]]
# Accuracy : 0.807909604519774
# __________________________________________________________________________________________________
# prediction from test data, model ke- 7
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80      2463
#     positive       0.83      0.76      0.79      2537
#
#    micro avg       0.80      0.80      0.80      5000
#    macro avg       0.80      0.80      0.80      5000
# weighted avg       0.80      0.80      0.80      5000
#
#
# Confusion Matrix :
#  [[2056  407]
#  [ 610 1927]]
# Accuracy : 0.7966
# __________________________________________________________________________________________________
# 3354 3354
# 3896 4285 3354
#
# Train Data= 3354 3354
# Predicton from train data model ke- 8
#
# Cross validation score: 0.8762548885719686
#                precision    recall  f1-score   support
#
#     negative       0.99      0.93      0.96      1857
#     positive       0.92      0.99      0.95      1497
#
#    micro avg       0.96      0.96      0.96      3354
#    macro avg       0.96      0.96      0.96      3354
# weighted avg       0.96      0.96      0.96      3354
#
#
# Confusion Matrix :
#  [[1733   16]
#  [ 124 1481]]
# Accuracy : 0.9582587954680978
# __________________________________________________________________________________________________
# Train Data= 3354 3354
# Test Data= 389 389
# prediction from test data, model ke- 8
#               precision    recall  f1-score   support
#
#     negative       0.81      0.86      0.83       205
#     positive       0.83      0.78      0.80       184
#
#    micro avg       0.82      0.82      0.82       389
#    macro avg       0.82      0.82      0.82       389
# weighted avg       0.82      0.82      0.82       389
#
#
# Confusion Matrix :
#  [[176  29]
#  [ 41 143]]
# Accuracy : 0.8200514138817481
# __________________________________________________________________________________________________
# prediction from test data, model ke- 8
#               precision    recall  f1-score   support
#
#     negative       0.76      0.84      0.80      2463
#     positive       0.83      0.74      0.78      2537
#
#    micro avg       0.79      0.79      0.79      5000
#    macro avg       0.79      0.79      0.79      5000
# weighted avg       0.79      0.79      0.79      5000
#
#
# Confusion Matrix :
#  [[2065  398]
#  [ 647 1890]]
# Accuracy : 0.791
# __________________________________________________________________________________________________
# 3644 3644
# 4285 4713 3644
#
# Train Data= 3644 3644
# Predicton from train data model ke- 9
#
# Cross validation score: 0.8815871631874984
#                precision    recall  f1-score   support
#
#     negative       0.99      0.93      0.96      2039
#     positive       0.92      0.99      0.96      1605
#
#    micro avg       0.96      0.96      0.96      3644
#    macro avg       0.96      0.96      0.96      3644
# weighted avg       0.96      0.96      0.96      3644
#
#
# Confusion Matrix :
#  [[1906   16]
#  [ 133 1589]]
# Accuracy : 0.9591108671789242
# __________________________________________________________________________________________________
# Train Data= 3644 3644
# Test Data= 428 428
# prediction from test data, model ke- 9
#               precision    recall  f1-score   support
#
#     negative       0.73      0.86      0.79       205
#     positive       0.84      0.70      0.77       223
#
#    micro avg       0.78      0.78      0.78       428
#    macro avg       0.79      0.78      0.78       428
# weighted avg       0.79      0.78      0.78       428
#
#
# Confusion Matrix :
#  [[176  29]
#  [ 66 157]]
# Accuracy : 0.7780373831775701
# __________________________________________________________________________________________________
# prediction from test data, model ke- 9
#               precision    recall  f1-score   support
#
#     negative       0.76      0.84      0.80      2463
#     positive       0.83      0.74      0.78      2537
#
#    micro avg       0.79      0.79      0.79      5000
#    macro avg       0.79      0.79      0.79      5000
# weighted avg       0.79      0.79      0.79      5000
#
#
# Confusion Matrix :
#  [[2071  392]
#  [ 662 1875]]
# Accuracy : 0.7892
# __________________________________________________________________________________________________
# 3959 3959
# 4713 5184 3959
#
# Train Data= 3959 3959
# Predicton from train data model ke- 10
#
# Cross validation score: 0.8871266765598067
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      2233
#     positive       0.92      0.99      0.95      1726
#
#    micro avg       0.96      0.96      0.96      3959
#    macro avg       0.96      0.96      0.96      3959
# weighted avg       0.96      0.96      0.96      3959
#
#
# Confusion Matrix :
#  [[2088   18]
#  [ 145 1708]]
# Accuracy : 0.9588279868653701
# __________________________________________________________________________________________________
# Train Data= 3959 3959
# Test Data= 471 471
# prediction from test data, model ke- 10
#               precision    recall  f1-score   support
#
#     negative       0.76      0.84      0.80       247
#     positive       0.80      0.71      0.75       224
#
#    micro avg       0.78      0.78      0.78       471
#    macro avg       0.78      0.77      0.77       471
# weighted avg       0.78      0.78      0.78       471
#
#
# Confusion Matrix :
#  [[207  40]
#  [ 65 159]]
# Accuracy : 0.7770700636942676
# __________________________________________________________________________________________________
# prediction from test data, model ke- 10
#               precision    recall  f1-score   support
#
#     negative       0.75      0.84      0.79      2463
#     positive       0.82      0.73      0.77      2537
#
#    micro avg       0.78      0.78      0.78      5000
#    macro avg       0.79      0.78      0.78      5000
# weighted avg       0.79      0.78      0.78      5000
#
#
# Confusion Matrix :
#  [[2063  400]
#  [ 692 1845]]
# Accuracy : 0.7816
# __________________________________________________________________________________________________
# 4322 4322
# 5184 5702 4322
#
# Train Data= 4322 4322
# Predicton from train data model ke- 11
#
# Cross validation score: 0.8937302861509918
#                precision    recall  f1-score   support
#
#     negative       0.99      0.93      0.96      2454
#     positive       0.92      0.99      0.95      1868
#
#    micro avg       0.96      0.96      0.96      4322
#    macro avg       0.95      0.96      0.96      4322
# weighted avg       0.96      0.96      0.96      4322
#
#
# Confusion Matrix :
#  [[2291   26]
#  [ 163 1842]]
# Accuracy : 0.9562702452568256
# __________________________________________________________________________________________________
# Train Data= 4322 4322
# Test Data= 518 518
# prediction from test data, model ke- 11
#               precision    recall  f1-score   support
#
#     negative       0.77      0.86      0.82       267
#     positive       0.83      0.73      0.78       251
#
#    micro avg       0.80      0.80      0.80       518
#    macro avg       0.80      0.80      0.80       518
# weighted avg       0.80      0.80      0.80       518
#
#
# Confusion Matrix :
#  [[230  37]
#  [ 67 184]]
# Accuracy : 0.7992277992277992
# __________________________________________________________________________________________________
# prediction from test data, model ke- 11
#               precision    recall  f1-score   support
#
#     negative       0.74      0.84      0.79      2463
#     positive       0.82      0.72      0.76      2537
#
#    micro avg       0.78      0.78      0.78      5000
#    macro avg       0.78      0.78      0.78      5000
# weighted avg       0.78      0.78      0.78      5000
#
#
# Confusion Matrix :
#  [[2061  402]
#  [ 717 1820]]
# Accuracy : 0.7762
# __________________________________________________________________________________________________
# 4710 4710
# 5702 6272 4710
#
# Train Data= 4710 4710
# Predicton from train data model ke- 12
#
# Cross validation score: 0.9014205166680643
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      2687
#     positive       0.92      0.99      0.95      2023
#
#    micro avg       0.96      0.96      0.96      4710
#    macro avg       0.95      0.96      0.96      4710
# weighted avg       0.96      0.96      0.96      4710
#
#
# Confusion Matrix :
#  [[2513   27]
#  [ 174 1996]]
# Accuracy : 0.9573248407643312
# __________________________________________________________________________________________________
# Train Data= 4710 4710
# Test Data= 570 570
# prediction from test data, model ke- 12
#               precision    recall  f1-score   support
#
#     negative       0.75      0.89      0.81       276
#     positive       0.88      0.72      0.79       294
#
#    micro avg       0.80      0.80      0.80       570
#    macro avg       0.81      0.81      0.80       570
# weighted avg       0.82      0.80      0.80       570
#
#
# Confusion Matrix :
#  [[246  30]
#  [ 82 212]]
# Accuracy : 0.8035087719298246
# __________________________________________________________________________________________________
# prediction from test data, model ke- 12
#               precision    recall  f1-score   support
#
#     negative       0.74      0.84      0.78      2463
#     positive       0.82      0.71      0.76      2537
#
#    micro avg       0.77      0.77      0.77      5000
#    macro avg       0.78      0.77      0.77      5000
# weighted avg       0.78      0.77      0.77      5000
#
#
# Confusion Matrix :
#  [[2068  395]
#  [ 740 1797]]
# Accuracy : 0.773
# __________________________________________________________________________________________________
# 5166 5166
# 6272 6899 5166
#
# Train Data= 5166 5166
# Predicton from train data model ke- 13
#
# Cross validation score: 0.9063602288363469
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      2971
#     positive       0.92      0.99      0.95      2195
#
#    micro avg       0.96      0.96      0.96      5166
#    macro avg       0.95      0.96      0.96      5166
# weighted avg       0.96      0.96      0.96      5166
#
#
# Confusion Matrix :
#  [[2782   32]
#  [ 189 2163]]
# Accuracy : 0.9572202864885792
# __________________________________________________________________________________________________
# Train Data= 5166 5166
# Test Data= 627 627
# prediction from test data, model ke- 13
#               precision    recall  f1-score   support
#
#     negative       0.71      0.86      0.78       295
#     positive       0.85      0.68      0.76       332
#
#    micro avg       0.77      0.77      0.77       627
#    macro avg       0.78      0.77      0.77       627
# weighted avg       0.78      0.77      0.77       627
#
#
# Confusion Matrix :
#  [[255  40]
#  [105 227]]
# Accuracy : 0.7687400318979266
# __________________________________________________________________________________________________
# prediction from test data, model ke- 13
#               precision    recall  f1-score   support
#
#     negative       0.73      0.84      0.78      2463
#     positive       0.82      0.70      0.75      2537
#
#    micro avg       0.77      0.77      0.77      5000
#    macro avg       0.77      0.77      0.77      5000
# weighted avg       0.78      0.77      0.77      5000
#
#
# Confusion Matrix :
#  [[2069  394]
#  [ 763 1774]]
# Accuracy : 0.7686
# __________________________________________________________________________________________________
# 5628 5628
# 6899 7588 5628
#
# Train Data= 5628 5628
# Predicton from train data model ke- 14
#
# Cross validation score: 0.9127556367752314
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      3262
#     positive       0.92      0.98      0.95      2366
#
#    micro avg       0.96      0.96      0.96      5628
#    macro avg       0.95      0.96      0.96      5628
# weighted avg       0.96      0.96      0.96      5628
#
#
# Confusion Matrix :
#  [[3058   36]
#  [ 204 2330]]
# Accuracy : 0.9573560767590619
# __________________________________________________________________________________________________
# Train Data= 5628 5628
# Test Data= 689 689
# prediction from test data, model ke- 14
#               precision    recall  f1-score   support
#
#     negative       0.76      0.85      0.80       346
#     positive       0.83      0.73      0.78       343
#
#    micro avg       0.79      0.79      0.79       689
#    macro avg       0.80      0.79      0.79       689
# weighted avg       0.79      0.79      0.79       689
#
#
# Confusion Matrix :
#  [[294  52]
#  [ 92 251]]
# Accuracy : 0.7910014513788098
# __________________________________________________________________________________________________
# prediction from test data, model ke- 14
#               precision    recall  f1-score   support
#
#     negative       0.73      0.84      0.78      2463
#     positive       0.82      0.69      0.75      2537
#
#    micro avg       0.77      0.77      0.77      5000
#    macro avg       0.77      0.77      0.76      5000
# weighted avg       0.77      0.77      0.76      5000
#
#
# Confusion Matrix :
#  [[2065  398]
#  [ 774 1763]]
# Accuracy : 0.7656
# __________________________________________________________________________________________________
# 6166 6166
# 7588 8346 6166
#
# Train Data= 6166 6166
# Predicton from train data model ke- 15
#
# Cross validation score: 0.9148762443467637
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.96      3575
#     positive       0.92      0.98      0.95      2591
#
#    micro avg       0.96      0.96      0.96      6166
#    macro avg       0.96      0.96      0.96      6166
# weighted avg       0.96      0.96      0.96      6166
#
#
# Confusion Matrix :
#  [[3364   42]
#  [ 211 2549]]
# Accuracy : 0.9589685371391502
# __________________________________________________________________________________________________
# Train Data= 6166 6166
# Test Data= 758 758
# prediction from test data, model ke- 15
#               precision    recall  f1-score   support
#
#     negative       0.70      0.83      0.76       361
#     positive       0.82      0.68      0.74       397
#
#    micro avg       0.75      0.75      0.75       758
#    macro avg       0.76      0.76      0.75       758
# weighted avg       0.76      0.75      0.75       758
#
#
# Confusion Matrix :
#  [[301  60]
#  [127 270]]
# Accuracy : 0.7532981530343008
# __________________________________________________________________________________________________
# prediction from test data, model ke- 15
#               precision    recall  f1-score   support
#
#     negative       0.73      0.84      0.78      2463
#     positive       0.82      0.69      0.75      2537
#
#    micro avg       0.77      0.77      0.77      5000
#    macro avg       0.77      0.77      0.76      5000
# weighted avg       0.77      0.77      0.76      5000
#
#
# Confusion Matrix :
#  [[2064  399]
#  [ 774 1763]]
# Accuracy : 0.7654
# __________________________________________________________________________________________________
# 6729 6729
# 8346 9180 6729
#
# Train Data= 6729 6729
# Predicton from train data model ke- 16
#
# Cross validation score: 0.9195853720540578
#                precision    recall  f1-score   support
#
#     negative       0.99      0.94      0.97      3907
#     positive       0.93      0.98      0.95      2822
#
#    micro avg       0.96      0.96      0.96      6729
#    macro avg       0.96      0.96      0.96      6729
# weighted avg       0.96      0.96      0.96      6729
#
#
# Confusion Matrix :
#  [[3688   46]
#  [ 219 2776]]
# Accuracy : 0.960618219646307
# __________________________________________________________________________________________________
# Train Data= 6729 6729
# Test Data= 834 834
# prediction from test data, model ke- 16
#               precision    recall  f1-score   support
#
#     negative       0.70      0.81      0.75       414
#     positive       0.78      0.65      0.71       420
#
#    micro avg       0.73      0.73      0.73       834
#    macro avg       0.74      0.73      0.73       834
# weighted avg       0.74      0.73      0.73       834
#
#
# Confusion Matrix :
#  [[337  77]
#  [145 275]]
# Accuracy : 0.7338129496402878
# __________________________________________________________________________________________________
# prediction from test data, model ke- 16
#               precision    recall  f1-score   support
#
#     negative       0.72      0.83      0.78      2463
#     positive       0.81      0.69      0.75      2537
#
#    micro avg       0.76      0.76      0.76      5000
#    macro avg       0.77      0.76      0.76      5000
# weighted avg       0.77      0.76      0.76      5000
#
#
# Confusion Matrix :
#  [[2055  408]
#  [ 781 1756]]
# Accuracy : 0.7622
# __________________________________________________________________________________________________
# 7400 7400
# 9180 10098 7400
#
# Train Data= 7400 7400
# Predicton from train data model ke- 17
#
# Cross validation score: 0.9252741008649501
#                precision    recall  f1-score   support
#
#     negative       0.99      0.95      0.97      4315
#     positive       0.93      0.98      0.96      3085
#
#    micro avg       0.96      0.96      0.96      7400
#    macro avg       0.96      0.96      0.96      7400
# weighted avg       0.96      0.96      0.96      7400
#
#
# Confusion Matrix :
#  [[4082   50]
#  [ 233 3035]]
# Accuracy : 0.9617567567567568
# __________________________________________________________________________________________________
# Train Data= 7400 7400
# Test Data= 918 918
# prediction from test data, model ke- 17
#               precision    recall  f1-score   support
#
#     negative       0.71      0.82      0.76       447
#     positive       0.80      0.69      0.74       471
#
#    micro avg       0.75      0.75      0.75       918
#    macro avg       0.76      0.75      0.75       918
# weighted avg       0.76      0.75      0.75       918
#
#
# Confusion Matrix :
#  [[367  80]
#  [148 323]]
# Accuracy : 0.7516339869281046
# __________________________________________________________________________________________________
# prediction from test data, model ke- 17
#               precision    recall  f1-score   support
#
#     negative       0.72      0.83      0.77      2463
#     positive       0.81      0.69      0.74      2537
#
#    micro avg       0.76      0.76      0.76      5000
#    macro avg       0.76      0.76      0.76      5000
# weighted avg       0.76      0.76      0.76      5000
#
#
# Confusion Matrix :
#  [[2043  420]
#  [ 790 1747]]
# Accuracy : 0.758
# __________________________________________________________________________________________________
# 8044 8044

# %% [markdown]
# # Test

# %%
import pprint
pp = pprint.PrettyPrinter()
    
prob=pipe.predict_proba(X_test)



prob_sum=[]
for data in range (0,len(prob)):
    prob_sum.append(prob[data][0]-prob[data][1])
    
pred=pipe.predict(X_test)

table=[]
result=[]

for i in range (0,len(X_test)) :
    if y_pred[i] == y_test[i] :
        result.append("true")

    else:
        result.append("false")
    
    table.append([result[i],pred[i],abs(prob_sum[i]),prob[i][0],prob[i][1]])

            
pp.pprint(table)
data_table=pd.DataFrame(table)
data_table
data_table.to_csv('prediction_naive_Bayes.csv')
# Out:
# [['true',
#   'negative',
#   0.9835088624347523,
#   0.9917544312173563,
#   0.008245568782603994],
#  ['true',
#   'positive',
#   0.9361144353072506,
#   0.03194278234637687,
#   0.9680572176536274],
#  ['true',
#   'positive',
#   0.9999275541892697,
#   3.622290535814308e-05,
#   0.9999637770946278],
#  ['true',
#   'negative',
#   0.9999967244747757,
#   0.9999983622373971,
#   1.6377626214171077e-06],
#  ['false',
#   'negative',
#   0.999999992940135,
#   0.9999999964700805,
#   3.529945613115239e-09],
#  ['true',
#   'positive',
#   0.999999831683445,
#   8.415828529483396e-08,
#   0.9999999158417303],
#  ['true',
#   'negative',
#   0.9998792738814696,
#   0.9999396369407579,
#   6.03630592883816e-05],
#  ['false',
#   'positive',
#   0.9011030047335767,
#   0.04944849763323186,
#   0.9505515023668086],
#  ['true', 'negative', 1.0, 1.0, 2.176357316970423e-27],
#  ['false',
#   'negative',
#   0.9999404842818982,
#   0.9999702421409529,
#   2.9757859054665832e-05],
#  ['true',
#   'positive',
#   0.9996593179233555,
#   0.00017034103833343618,
#   0.999829658961689],
#  ['false',
#   'negative',
#   0.9999941804625493,
#   0.9999970902312313,
#   2.909768681957321e-06],
#  ['false',
#   'negative',
#   0.9999999458421114,
#   0.9999999729210461,
#   2.70789347464859e-08],
#  ['true',
#   'negative',
#   0.9999947223340172,
#   0.9999973611670187,
#   2.6388330014643526e-06],
#  ['true',
#   'negative',
#   0.995655781705867,
#   0.9978278908529391,
#   0.002172109147072115],
#  ['false',
#   'negative',
#   0.9999774828143851,
#   0.9999887414072057,
#   1.1258592820612505e-05],
#  ['true',
#   'positive',
#   0.9243673310768263,
#   0.037816334461573196,
#   0.9621836655383995],
#  ['true',
#   'positive',
#   0.9277321328041742,
#   0.03613393359792151,
#   0.9638660664020957],
#  ['true',
#   'negative',
#   0.9988629238525594,
#   0.9994314619262922,
#   0.0005685380737328353],
#  ['true',
#   'positive',
#   0.9999989016419542,
#   5.491789203080619e-07,
#   0.9999994508208745],
#  ['true',
#   'positive',
#   0.9990526576755746,
#   0.00047367116220207057,
#   0.9995263288377767],
#  ['true',
#   'positive',
#   0.999994536464745,
#   2.731767626037156e-06,
#   0.999997268232371],
#  ['true',
#   'negative',
#   0.9999999995356937,
#   0.9999999997678515,
#   2.321577557665332e-10],
#  ['true', 'negative', 1.0, 1.0, 1.9942741610844274e-17],
#  ['false',
#   'negative',
#   0.9999972234987307,
#   0.9999986117493878,
#   1.388250657111018e-06],
#  ['true', 'positive', 1.0, 2.5223408527205854e-22, 1.0],
#  ['true',
#   'positive',
#   0.9963370807010313,
#   0.0018314596494954781,
#   0.9981685403505268],
#  ['false',
#   'negative',
#   0.9867782220460725,
#   0.9933891110230544,
#   0.006610888976981869],
#  ['false',
#   'negative',
#   0.9999990152948295,
#   0.9999995076474382,
#   4.923526086516755e-07],
#  ['false',
#   'negative',
#   0.9528869597349803,
#   0.9764434798674811,
#   0.02355652013250087],
#  ['false',
#   'negative',
#   0.9967305478743949,
#   0.9983652739372173,
#   0.0016347260628224699],
#  ['true',
#   'negative',
#   0.912517028985108,
#   0.956258514492552,
#   0.04374148550744395],
#  ['true',
#   'negative',
#   0.8891539537125046,
#   0.9445769768562083,
#   0.05542302314370374],
#  ['true', 'positive', 0.9999999999999993, 6.833310687616655e-16, 1.0],
#  ['true',
#   'negative',
#   0.9999999719043352,
#   0.9999999859521723,
#   1.4047837139356663e-08],
#  ['true',
#   'positive',
#   0.9999990160554824,
#   4.919722380413332e-07,
#   0.9999995080277204],
#  ['true',
#   'positive',
#   0.99999999999909,
#   4.552735571632271e-13,
#   0.9999999999995453],
#  ['true',
#   'negative',
#   0.9999906873924466,
#   0.999995343696225,
#   4.6563037784045266e-06],
#  ['false',
#   'positive',
#   0.92032129641733,
#   0.03983935179132738,
#   0.9601606482086573],
#  ['true',
#   'negative',
#   0.9999993944280955,
#   0.9999996972140256,
#   3.027859301568527e-07],
#  ['true',
#   'negative',
#   0.9998092786565734,
#   0.9999046393282779,
#   9.53606717044501e-05],
#  ['false',
#   'negative',
#   0.9994452114025669,
#   0.9997226057012889,
#   0.00027739429872200143],
#  ['true', 'negative', 0.999999999999997, 1.0, 2.9592440893884916e-15],
#  ['false',
#   'negative',
#   0.9999912408308083,
#   0.9999956204153885,
#   4.379584580217952e-06],
#  ['true',
#   'negative',
#   0.9999999999948826,
#   0.999999999997442,
#   2.5593515684367557e-12],
#  ['true', 'positive', 0.9999999999999999, 1.5078884709411156e-16, 1.0],
#  ['false',
#   'positive',
#   0.9999999999993218,
#   3.3712972348140004e-13,
#   0.9999999999996589],
#  ['true',
#   'positive',
#   0.999999998498443,
#   7.507691591446956e-10,
#   0.9999999992492121],
#  ['true', 'positive', 1.0, 2.4165111657358234e-19, 1.0],
#  ['false',
#   'positive',
#   0.9912503484207891,
#   0.004374825789641108,
#   0.9956251742104302],
#  ['false',
#   'negative',
#   0.7706582459859461,
#   0.8853291229929691,
#   0.114670877007023],
#  ['true',
#   'negative',
#   0.9853458169562475,
#   0.9926729084781107,
#   0.007327091521863303],
#  ['false',
#   'positive',
#   0.9999999878023554,
#   6.098800435519802e-09,
#   0.9999999939011559],
#  ['true', 'positive', 0.9999999999999881, 1.1850848578209202e-14, 1.0],
#  ['false', 'positive', 0.9999999999999998, 1.7709331749569019e-16, 1.0],
#  ['true',
#   'negative',
#   0.9973777006069547,
#   0.9986888503034773,
#   0.001311149696522563],
#  ['false',
#   'negative',
#   0.9695080196040693,
#   0.9847540098020411,
#   0.015245990197971761],
#  ['true',
#   'negative',
#   0.9999999934425392,
#   0.9999999967212716,
#   3.278732395662684e-09],
#  ['true',
#   'positive',
#   0.9999999996261105,
#   1.8698826132877533e-10,
#   0.9999999998130988],
#  ['true',
#   'negative',
#   0.9999171046500946,
#   0.999958552325058,
#   4.144767496337847e-05],
#  ['false',
#   'negative',
#   0.5308087763497853,
#   0.765404388174913,
#   0.23459561182512773],
#  ['true', 'positive', 1.0, 1.6749831696616242e-38, 1.0],
#  ['true',
#   'positive',
#   0.9861383494123859,
#   0.006930825293800206,
#   0.993069174706186],
#  ['true', 'positive', 1.0, 1.0111666208729987e-20, 1.0],
#  ['true',
#   'positive',
#   0.9151365548883105,
#   0.042431722555845285,
#   0.9575682774441557],
#  ['false',
#   'negative',
#   0.9999820744713414,
#   0.9999910372356796,
#   8.962764338286082e-06],
#  ['true', 'positive', 0.999999999999999, 9.466116626763344e-16, 1.0],
#  ['false',
#   'negative',
#   0.9996800966753248,
#   0.9998400483376567,
#   0.00015995166233192642],
#  ['false',
#   'negative',
#   0.9999977570625703,
#   0.9999988785313612,
#   1.1214687908318207e-06],
#  ['true',
#   'negative',
#   0.999999999960691,
#   0.9999999999803322,
#   1.964117796203403e-11],
#  ['true',
#   'positive',
#   0.7476614989140948,
#   0.12616925054294587,
#   0.8738307494570408],
#  ['true', 'positive', 0.9999999999999617, 3.8282357992737166e-14, 1.0],
#  ['true',
#   'negative',
#   0.999999999992735,
#   0.999999999996362,
#   3.6269710862852765e-12],
#  ['false', 'negative', 1.0, 1.0, 5.051910742117547e-18],
#  ['false',
#   'negative',
#   0.9999995104524932,
#   0.999999755226243,
#   2.447737497196105e-07],
#  ['false', 'positive', 0.9999999999999996, 4.11312396126424e-16, 1.0],
#  ['true',
#   'positive',
#   0.025102306629255333,
#   0.4874488466853895,
#   0.5125511533146448],
#  ['true',
#   'positive',
#   0.9999243052491062,
#   3.784737545854785e-05,
#   0.9999621526245648],
#  ['false',
#   'positive',
#   0.999999833220157,
#   8.338986888784717e-08,
#   0.9999999166100259],
#  ['true',
#   'negative',
#   0.999999999995022,
#   0.9999999999974989,
#   2.476947769111727e-12],
#  ['false', 'positive', 0.581002810140373, 0.209498594929807, 0.79050140507018],
#  ['true', 'negative', 0.9999999999999795, 1.0, 2.0520642287867046e-14],
#  ['true',
#   'positive',
#   0.9999985848492405,
#   7.075753868022054e-07,
#   0.9999992924246274],
#  ['false',
#   'positive',
#   0.7308590777179014,
#   0.13457046114104648,
#   0.8654295388589478],
#  ['false',
#   'negative',
#   0.999999999928135,
#   0.999999999964075,
#   3.593994882430204e-11],
#  ['true',
#   'negative',
#   0.9999962742564701,
#   0.9999981371282459,
#   1.86287177586274e-06],
#  ['false',
#   'negative',
#   0.8996330351241655,
#   0.94981651756209,
#   0.05018348243792444],
#  ['true',
#   'negative',
#   0.9999990294370349,
#   0.9999995147185287,
#   4.852814937598093e-07],
#  ['true',
#   'negative',
#   0.9999953214572778,
#   0.9999976607286462,
#   2.339271368386752e-06],
#  ['true',
#   'negative',
#   0.999989071002874,
#   0.999994535501438,
#   5.464498563952213e-06],
#  ['true',
#   'negative',
#   0.9999997757481958,
#   0.9999998878740889,
#   1.1212589308880598e-07],
#  ['false',
#   'negative',
#   0.25011201379020853,
#   0.6250560068950973,
#   0.3749439931048888],
#  ['true',
#   'positive',
#   0.9983585342203072,
#   0.0008207328898420038,
#   0.9991792671101491],
#  ['true',
#   'negative',
#   0.9999869946180723,
#   0.9999934973091026,
#   6.502691030299049e-06],
#  ['false',
#   'negative',
#   0.9997894051115912,
#   0.9998947025558199,
#   0.00010529744422870633],
#  ['true',
#   'positive',
#   0.8119613746518816,
#   0.09401931267404728,
#   0.9059806873259288],
#  ['true',
#   'positive',
#   0.9999932303373563,
#   3.3848313286156827e-06,
#   0.999996615168685],
#  ['true',
#   'negative',
#   0.9999999389276573,
#   0.9999999694638295,
#   3.053617229351131e-08],
#  ['true',
#   'negative',
#   0.9999999999872432,
#   0.9999999999936335,
#   6.390371458655212e-12],
#  ['true', 'negative', 1.0, 1.0, 6.510970033472936e-27],
#  ['true',
#   'positive',
#   0.9736563408893075,
#   0.013171829555342787,
#   0.9868281704446503],
#  ['false',
#   'positive',
#   0.999988201285175,
#   5.899357371099231e-06,
#   0.999994100642546],
#  ['true',
#   'positive',
#   0.9999999999551135,
#   2.2433340025405627e-11,
#   0.9999999999775468],
#  ['true',
#   'negative',
#   0.9998120797236234,
#   0.999906039861812,
#   9.396013818868654e-05],
#  ['true', 'positive', 1.0, 3.351695109683213e-22, 1.0],
#  ['false',
#   'negative',
#   0.6282859821322921,
#   0.8141429910661447,
#   0.18585700893385257],
#  ['false',
#   'positive',
#   0.9999999998617182,
#   6.916026116538702e-11,
#   0.9999999999308784],
#  ['true',
#   'negative',
#   0.8095312642237091,
#   0.9047656321118626,
#   0.09523436788815348],
#  ['true',
#   'negative',
#   0.9999999992610761,
#   0.9999999996305178,
#   3.6944174390667267e-10],
#  ['true',
#   'negative',
#   0.9999999952482251,
#   0.9999999976241156,
#   2.375890483225557e-09],
#  ['true', 'negative', 1.0, 1.0, 6.211125093935877e-19],
#  ['false',
#   'negative',
#   0.9792236935133573,
#   0.9896118467566831,
#   0.010388153243325881],
#  ['true',
#   'positive',
#   0.999999973898084,
#   1.3050951327574034e-08,
#   0.9999999869490354],
#  ['true', 'positive', 1.0, 4.1099075973696075e-20, 1.0],
#  ['false',
#   'negative',
#   0.564861790371043,
#   0.7824308951855162,
#   0.2175691048144732],
#  ['true', 'negative', 0.9999999999999978, 1.0, 2.2265776744565896e-15],
#  ['true',
#   'positive',
#   0.9924982788134445,
#   0.003750860593273997,
#   0.9962491394067186],
#  ['true',
#   'negative',
#   0.9999999999870529,
#   0.9999999999936335,
#   6.580586968415423e-12],
#  ['true', 'positive', 1.0, 1.8335244142713703e-41, 1.0],
#  ['true',
#   'positive',
#   0.9999999999952522,
#   2.3602955001910074e-12,
#   0.9999999999976126],
#  ['false',
#   'negative',
#   0.9999949980870837,
#   0.99999749904356,
#   2.500956476211911e-06],
#  ['true', 'negative', 1.0, 1.0, 5.012753474169781e-19],
#  ['true',
#   'negative',
#   0.999959166091568,
#   0.9999795830457696,
#   2.041695420163096e-05],
#  ['true',
#   'negative',
#   0.9999999999994373,
#   0.9999999999997158,
#   2.783994481905302e-13],
#  ['true',
#   'positive',
#   0.9999999999977071,
#   1.1560790269941607e-12,
#   0.9999999999988631],
#  ['true',
#   'positive',
#   0.9999999995671919,
#   2.1640520596044142e-10,
#   0.9999999997835971],
#  ['true',
#   'positive',
#   0.99276973090735,
#   0.0036151345463362574,
#   0.9963848654536862],
#  ['true',
#   'positive',
#   0.9999482841273584,
#   2.585793631738375e-05,
#   0.9999741420636757],
#  ['true',
#   'negative',
#   0.9999127565573209,
#   0.9999563782786351,
#   4.3621721314211785e-05],
#  ['true', 'negative', 0.9999999999999998, 1.0, 1.9773495442783818e-16],
#  ['true',
#   'positive',
#   0.9999647755164899,
#   1.7612241761640367e-05,
#   0.9999823877582515],
#  ['true',
#   'positive',
#   0.9999999999990594,
#   4.858182696414018e-13,
#   0.9999999999995453],
#  ['true',
#   'positive',
#   0.9999984396815705,
#   7.801592092661729e-07,
#   0.9999992198407798],
#  ['true',
#   'positive',
#   0.9999999901713118,
#   4.914347303640751e-09,
#   0.9999999950856591],
#  ['true',
#   'positive',
#   0.9999999297626366,
#   3.51187040490085e-08,
#   0.9999999648813407],
#  ['true',
#   'positive',
#   0.9986109120541954,
#   0.0006945439729063833,
#   0.9993054560271017],
#  ['true',
#   'positive',
#   0.7843605062549988,
#   0.10781974687252602,
#   0.8921802531275248],
#  ['false',
#   'negative',
#   0.9912840503259672,
#   0.9956420251629868,
#   0.0043579748370195966],
#  ['true',
#   'negative',
#   0.9999955527821799,
#   0.9999977763910972,
#   2.223608917376444e-06],
#  ['true',
#   'positive',
#   0.9999989694212963,
#   5.152893791461839e-07,
#   0.9999994847106755],
#  ['true',
#   'negative',
#   0.9999998146284006,
#   0.9999999073141951,
#   9.26857945028397e-08],
#  ['true',
#   'positive',
#   0.9796680227795909,
#   0.01016598861019613,
#   0.989834011389787],
#  ['true',
#   'negative',
#   0.9999323005612085,
#   0.9999661502806033,
#   3.384971939480538e-05],
#  ['true',
#   'positive',
#   0.9541672012816342,
#   0.02291639935918194,
#   0.9770836006408162],
#  ['true', 'negative', 1.0, 1.0, 4.302910107143371e-40],
#  ['true',
#   'negative',
#   0.9999996355902973,
#   0.999999817795145,
#   1.8220484781266272e-07],
#  ['true',
#   'negative',
#   0.99999998662326,
#   0.9999999933116328,
#   6.688372851962404e-09],
#  ['true',
#   'positive',
#   0.9571037281708745,
#   0.021448135914576616,
#   0.9785518640854511],
#  ['false',
#   'positive',
#   0.9999999999994603,
#   3.1226131735321363e-13,
#   0.9999999999997726],
#  ['true', 'negative', 1.0, 1.0, 1.2074550606628985e-19],
#  ['true', 'negative', 1.0, 1.0, 9.094429901649512e-22],
#  ['true',
#   'positive',
#   0.9667863715733273,
#   0.01660681421333884,
#   0.9833931857866661],
#  ['false',
#   'positive',
#   0.875860432038022,
#   0.0620697839809953,
#   0.9379302160190173],
#  ['true', 'negative', 1.0, 1.0, 7.253312780379816e-24],
#  ['true', 'positive', 0.9999999999999987, 1.3773430442674737e-15, 1.0],
#  ['true',
#   'positive',
#   0.9999769622899255,
#   1.1518855034026175e-05,
#   0.9999884811449595],
#  ['true',
#   'positive',
#   0.5633988363408284,
#   0.21830058182958378,
#   0.7816994181704122],
#  ['true',
#   'negative',
#   0.9999611108425861,
#   0.9999805554212896,
#   1.9444578703509377e-05],
#  ['true',
#   'positive',
#   0.9998203176407,
#   8.984117966255868e-05,
#   0.9999101588203626],
#  ['true',
#   'positive',
#   0.9585418097821993,
#   0.020729095108910706,
#   0.97927090489111],
#  ['false',
#   'negative',
#   0.9999999999807246,
#   0.9999999999903366,
#   9.611930786302139e-12],
#  ['true',
#   'positive',
#   0.9999999726877761,
#   1.3656104253426256e-08,
#   0.9999999863438803],
#  ['true',
#   'negative',
#   0.9997817124517273,
#   0.999890856225868,
#   0.00010914377414075188],
#  ['true',
#   'negative',
#   0.9874641464654279,
#   0.9937320732326572,
#   0.006267926767229261],
#  ['false',
#   'positive',
#   0.29197579649247857,
#   0.35401210175374925,
#   0.6459878982462278],
#  ['true', 'positive', 1.0, 2.528228553599504e-38, 1.0],
#  ['true',
#   'positive',
#   0.9999999992228051,
#   3.886132962803475e-10,
#   0.9999999996114184],
#  ['true',
#   'positive',
#   0.9971976868227449,
#   0.0014011565886357974,
#   0.9985988434113807],
#  ['true',
#   'positive',
#   0.9980152841391204,
#   0.0009923579304327965,
#   0.9990076420695533],
#  ['true',
#   'positive',
#   0.9999564990769317,
#   2.1750461545422012e-05,
#   0.9999782495384771],
#  ['true',
#   'positive',
#   0.9999999999984335,
#   7.707556277964409e-13,
#   0.9999999999992042],
#  ['true', 'positive', 1.0, 1.7048066058612428e-20, 1.0],
#  ['true',
#   'positive',
#   0.9999996798649653,
#   1.6006750424962718e-07,
#   0.9999998399324695],
#  ['true', 'negative', 1.0, 1.0, 3.0284791869312377e-22],
#  ['true', 'negative', 0.9999999999999996, 1.0, 4.808572893635585e-16],
#  ['true',
#   'positive',
#   0.9999957127122799,
#   2.143643861082501e-06,
#   0.999997856356141],
#  ['true',
#   'negative',
#   0.9999798165262768,
#   0.9999899082631503,
#   1.0091736873488241e-05],
#  ['true',
#   'negative',
#   0.9968989423859004,
#   0.9984494711929551,
#   0.0015505288070547282],
#  ['false',
#   'positive',
#   0.9999999996882428,
#   1.5589254372565323e-10,
#   0.9999999998441353],
#  ['true', 'negative', 0.9999999999999977, 1.0, 2.3061678787823957e-15],
#  ['false',
#   'negative',
#   0.9999999980043583,
#   0.9999999990021706,
#   9.978123135830423e-10],
#  ['false',
#   'negative',
#   0.9980961349075225,
#   0.9990480674537532,
#   0.0009519325462307555],
#  ['true',
#   'positive',
#   0.8804232633527778,
#   0.059788368323623345,
#   0.9402116316764011],
#  ['true', 'negative', 1.0, 1.0, 4.8248082768335455e-28],
#  ['true',
#   'negative',
#   0.9999999999766936,
#   0.9999999999883471,
#   1.1653404174675565e-11],
#  ['true', 'negative', 0.9999999999999996, 1.0, 4.958740325029309e-16],
#  ['false',
#   'negative',
#   0.9124193638991598,
#   0.9562096819495816,
#   0.0437903180504218],
#  ['true',
#   'negative',
#   0.9999999999838386,
#   0.9999999999919282,
#   8.089610673958215e-12],
#  ['false',
#   'positive',
#   0.9999714065259033,
#   1.42967370422215e-05,
#   0.9999857032629456],
#  ['true',
#   'negative',
#   0.9999999999473249,
#   0.9999999999736247,
#   2.62997447696169e-11],
#  ['true',
#   'negative',
#   0.9999881994724852,
#   0.9999940997362399,
#   5.900263754708256e-06],
#  ['false', 'positive', 1.0, 3.420536200795721e-18, 1.0],
#  ['false',
#   'negative',
#   0.9999998564586698,
#   0.9999999282293314,
#   7.177066148786079e-08],
#  ['true',
#   'positive',
#   0.9520804623485173,
#   0.02395976882574346,
#   0.9760402311742608],
#  ['false',
#   'positive',
#   0.9999999990682971,
#   4.65814253740151e-10,
#   0.9999999995341113],
#  ['true',
#   'positive',
#   0.9945729872048943,
#   0.002713506397574984,
#   0.9972864936024692],
#  ['true',
#   'positive',
#   0.9981686756787888,
#   0.0009156621605956464,
#   0.9990843378393844],
#  ['true',
#   'negative',
#   0.9999999999998147,
#   0.9999999999998863,
#   7.163630118511192e-14],
#  ['true',
#   'negative',
#   0.9999999909931542,
#   0.9999999954965801,
#   4.50342596324827e-09],
#  ['false',
#   'negative',
#   0.9999627074512188,
#   0.9999813537256327,
#   1.864627441383586e-05],
#  ['false',
#   'positive',
#   0.8460138823216165,
#   0.07699305883917942,
#   0.9230069411607958],
#  ['true',
#   'positive',
#   0.7804981144020979,
#   0.10975094279894021,
#   0.8902490572010382],
#  ['true',
#   'positive',
#   0.9999998978082292,
#   5.109590511806876e-08,
#   0.9999999489041342],
#  ['false',
#   'positive',
#   0.999999999999725,
#   1.6132159869111732e-13,
#   0.9999999999998863],
#  ['true',
#   'positive',
#   0.9981748217920727,
#   0.0009125891039167989,
#   0.9990874108959895],
#  ['true', 'positive', 1.0, 7.714660031623387e-18, 1.0],
#  ['true',
#   'negative',
#   0.999999992080321,
#   0.9999999960401738,
#   3.95985273938903e-09],
#  ['true', 'positive', 0.9999999999999986, 1.4662818507775765e-15, 1.0],
#  ['false',
#   'negative',
#   0.9999999112891182,
#   0.9999999556445697,
#   4.435545140919911e-08],
#  ['true',
#   'positive',
#   0.9999999997471216,
#   1.2645865565209496e-10,
#   0.9999999998735802],
#  ['false',
#   'positive',
#   0.9999814336373372,
#   9.283181336820569e-06,
#   0.999990716818674],
#  ['false',
#   'positive',
#   0.9988360810881675,
#   0.0005819594559041025,
#   0.9994180405440716],
#  ['true',
#   'positive',
#   0.9999884278469474,
#   5.786076537670129e-06,
#   0.9999942139234851],
#  ['true', 'negative', 1.0, 1.0, 3.6518591955210975e-28],
#  ['false', 'negative', 0.9999999999999825, 1.0, 1.757171459675912e-14],
#  ['false',
#   'positive',
#   0.9999133836230286,
#   4.330818845782201e-05,
#   0.9999566918114864],
#  ['true',
#   'positive',
#   0.999998327410186,
#   8.362948924205955e-07,
#   0.9999991637050785],
#  ['true', 'positive', 0.9999999999999998, 1.9313397547450434e-16, 1.0],
#  ['true',
#   'positive',
#   0.999999997047868,
#   1.476022088909789e-09,
#   0.9999999985238901],
#  ['false',
#   'negative',
#   0.8966678363795455,
#   0.9483339181897771,
#   0.051666081810231565],
#  ['false',
#   'positive',
#   0.3648143926680724,
#   0.317592803665988,
#   0.6824071963340604],
#  ['false',
#   'negative',
#   0.9999652192739311,
#   0.9999826096369695,
#   1.73903630383384e-05],
#  ['true',
#   'negative',
#   0.9999920064524646,
#   0.9999960032262443,
#   3.996773779750706e-06],
#  ['true',
#   'negative',
#   0.999995734133547,
#   0.9999978670667825,
#   2.1329332355260696e-06],
#  ['false',
#   'positive',
#   0.9999752159477542,
#   1.239202611046531e-05,
#   0.9999876079738647],
#  ['true',
#   'negative',
#   0.9999951134535303,
#   0.9999975567267546,
#   2.443273224341336e-06],
#  ['true',
#   'positive',
#   0.9999740098141318,
#   1.2995092933579894e-05,
#   0.9999870049070654],
#  ['true',
#   'negative',
#   0.9999862801225357,
#   0.9999931400612886,
#   6.859938752893473e-06],
#  ['true',
#   'negative',
#   0.9998554442801764,
#   0.9999277221401023,
#   7.227785992597023e-05],
#  ['false',
#   'positive',
#   0.29953046487641494,
#   0.35023476756178545,
#   0.6497652324382004],
#  ['true',
#   'negative',
#   0.9999998836527023,
#   0.9999999418263331,
#   5.817363077706605e-08],
#  ['false',
#   'negative',
#   0.7301386539489122,
#   0.865069326974452,
#   0.13493067302553988],
#  ['true',
#   'negative',
#   0.9999999998257966,
#   0.9999999999129159,
#   8.711935061684835e-11],
#  ['true', 'negative', 1.0, 1.0, 4.425801998685608e-25],
#  ['true',
#   'positive',
#   0.9992115587479264,
#   0.0003942206260431312,
#   0.9996057793739695],
#  ['false',
#   'negative',
#   0.9976104892210647,
#   0.9988052446105194,
#   0.0011947553894548124],
#  ['false',
#   'negative',
#   0.5765045270723987,
#   0.7882522635361897,
#   0.21174773646379103],
#  ['true', 'positive', 1.0, 2.0936991273956322e-22, 1.0],
#  ['true',
#   'positive',
#   0.9999980706891434,
#   9.64655425383494e-07,
#   0.9999990353445688],
#  ['true',
#   'negative',
#   0.9999999999933965,
#   0.9999999999967031,
#   3.3065704805742603e-12],
#  ['true',
#   'negative',
#   0.9778284602368055,
#   0.988914230118514,
#   0.011085769881708507],
#  ['true',
#   'negative',
#   0.9999003680085697,
#   0.9999501840042856,
#   4.98159957158349e-05],
#  ['false',
#   'negative',
#   0.9999999999985902,
#   0.9999999999993179,
#   7.27650740052939e-13],
#  ['true',
#   'positive',
#   0.9999999779157532,
#   1.1042071677671977e-08,
#   0.9999999889578249],
#  ['true',
#   'negative',
#   0.9999986696741797,
#   0.9999993348371784,
#   6.651629987129793e-07],
#  ['true',
#   'negative',
#   0.9999970654424589,
#   0.9999985327212322,
#   1.4672787732877526e-06],
#  ['true',
#   'positive',
#   0.9996149752977243,
#   0.00019251235113558918,
#   0.9998074876488598],
#  ['true',
#   'positive',
#   0.9999999996452964,
#   1.7735217668264854e-10,
#   0.9999999998226485],
#  ['true',
#   'negative',
#   0.9999828129226651,
#   0.9999914064613669,
#   8.593538701742886e-06],
#  ['true',
#   'negative',
#   0.999999999999662,
#   0.9999999999998295,
#   1.673679957856936e-13],
#  ['false',
#   'positive',
#   0.9999998287073907,
#   8.56462927170418e-08,
#   0.9999999143536834],
#  ['true',
#   'positive',
#   0.9999997226086919,
#   1.3869564953473734e-07,
#   0.9999998613043414],
#  ['false',
#   'negative',
#   0.9998778910869336,
#   0.9999389455434801,
#   6.105445654651494e-05],
#  ['true',
#   'negative',
#   0.99740846089812,
#   0.9987042304490681,
#   0.001295769550948152],
#  ['true',
#   'negative',
#   0.999994342430757,
#   0.999997171215363,
#   2.8287846059515194e-06],
#  ['false',
#   'negative',
#   0.936204930592759,
#   0.9681024652963813,
#   0.03189753470362235],
#  ['true',
#   'negative',
#   0.9999999664753596,
#   0.9999999832376717,
#   1.6762312118621305e-08],
#  ['true',
#   'positive',
#   0.9999999993811,
#   3.0944443059382893e-10,
#   0.9999999996905444],
#  ['true',
#   'positive',
#   0.9996497953760598,
#   0.00017510231196407917,
#   0.9998248976880239],
#  ['false',
#   'positive',
#   0.9999990016764514,
#   4.99161830645291e-07,
#   0.999999500838282],
#  ['true',
#   'positive',
#   0.9998893249037111,
#   5.5337548143197325e-05,
#   0.9999446624518543],
#  ['true',
#   'negative',
#   0.99999940600045,
#   0.9999997030002291,
#   2.9699977913197945e-07],
#  ['true',
#   'negative',
#   0.999999981615712,
#   0.9999999908078507,
#   9.192138679579387e-09],
#  ['true',
#   'negative',
#   0.9999999999188691,
#   0.9999999999594138,
#   4.0544695748629137e-11],
#  ['false',
#   'positive',
#   0.42457306902245917,
#   0.28771346548876153,
#   0.7122865345112207],
#  ['false',
#   'negative',
#   0.98574243815234,
#   0.992871219076167,
#   0.007128780923827081],
#  ['true',
#   'positive',
#   0.9245543019564637,
#   0.037722849021761116,
#   0.9622771509782249],
#  ['false',
#   'negative',
#   0.8471075718362424,
#   0.9235537859181324,
#   0.07644621408189002],
#  ['false',
#   'negative',
#   0.999999997576987,
#   0.9999999987884962,
#   1.2115092195885758e-09],
#  ['true',
#   'negative',
#   0.9999993392027761,
#   0.9999996696013773,
#   3.3039860123317245e-07],
#  ['true',
#   'negative',
#   0.9473393807743593,
#   0.9736696903871555,
#   0.02633030961279611],
#  ['false',
#   'negative',
#   0.11168301438163303,
#   0.5558415071908153,
#   0.44415849280918224],
#  ['false',
#   'positive',
#   0.9953831020619087,
#   0.0023084489690600265,
#   0.9976915510309687],
#  ['true',
#   'positive',
#   0.9999759728920251,
#   1.2013554005106525e-05,
#   0.9999879864460303],
#  ['true',
#   'negative',
#   0.9997846898978338,
#   0.9998923449489101,
#   0.00010765505107634077],
#  ['true', 'positive', 1.0, 2.373271662103061e-17, 1.0],
#  ['true',
#   'positive',
#   0.9954942568888614,
#   0.002252871555581608,
#   0.997747128444443],
#  ['true',
#   'negative',
#   0.9999999999998932,
#   0.9999999999999432,
#   5.000871324972539e-14],
#  ['true',
#   'negative',
#   0.9999999199886177,
#   0.9999999599942847,
#   4.000566694995334e-08],
#  ['false',
#   'negative',
#   0.4471238229536954,
#   0.7235619114768493,
#   0.27643808852315394],
#  ['false',
#   'negative',
#   0.999999447439229,
#   0.999999723719621,
#   2.7628039202906427e-07],
#  ['true', 'positive', 0.9999999999999889, 1.1097116332485674e-14, 1.0],
#  ['false',
#   'positive',
#   0.9999999812218582,
#   9.388973253996609e-09,
#   0.9999999906108314],
#  ['true',
#   'negative',
#   0.9581276981468768,
#   0.9790638490734327,
#   0.020936150926555926],
#  ['true',
#   'positive',
#   0.9999998620898906,
#   6.895506569916423e-08,
#   0.9999999310449562],
#  ['true',
#   'positive',
#   0.9858180301707326,
#   0.007090984914646865,
#   0.9929090150853794],
#  ['true',
#   'negative',
#   0.9999999954166057,
#   0.9999999977083007,
#   2.2916950262825828e-09],
#  ['true',
#   'negative',
#   0.9999127153794719,
#   0.9999563576897104,
#   4.3642310238403814e-05],
#  ['true',
#   'negative',
#   0.9979521214150846,
#   0.9989760607075293,
#   0.0010239392924447307],
#  ['true',
#   'positive',
#   0.9982440267922057,
#   0.0008779866039066113,
#   0.9991220133961123],
#  ['false',
#   'negative',
#   0.9999098136343336,
#   0.9999549068171786,
#   4.509318284494056e-05],
#  ['true',
#   'negative',
#   0.9999999999803142,
#   0.9999999999901661,
#   9.851843915233193e-12],
#  ['true',
#   'positive',
#   0.999330323596228,
#   0.00033483820187384203,
#   0.9996651617981018],
#  ['true',
#   'positive',
#   0.18425238465902383,
#   0.407873807670486,
#   0.5921261923295098],
#  ['false',
#   'negative',
#   0.9990777847290622,
#   0.999538892364548,
#   0.0004611076354857376],
#  ['true',
#   'negative',
#   0.9985378731287544,
#   0.9992689365643818,
#   0.0007310634356273446],
#  ['false',
#   'negative',
#   0.9507934458639278,
#   0.9753967229319579,
#   0.02460327706803014],
#  ['true', 'negative', 1.0, 1.0, 4.936371916758043e-18],
#  ['false',
#   'positive',
#   0.9982415607753748,
#   0.0008792196123363547,
#   0.9991207803877112],
#  ['true',
#   'negative',
#   0.9821206591821756,
#   0.9910603295910843,
#   0.00893967040890859],
#  ['true', 'positive', 1.0, 1.6253310478245724e-40, 1.0],
#  ['true', 'negative', 0.9999999999999791, 1.0, 2.0828878241074597e-14],
#  ['true', 'positive', 1.0, 8.260228010511507e-24, 1.0],
#  ['true',
#   'positive',
#   0.9965365254890517,
#   0.0017317372554624736,
#   0.9982682627445142],
#  ['true', 'positive', 0.9999999999999996, 3.9639670259436225e-16, 1.0],
#  ['false',
#   'positive',
#   0.9999976734031503,
#   1.1632984373067607e-06,
#   0.9999988367015876],
#  ['true',
#   'positive',
#   0.997832900232911,
#   0.0010835498835373382,
#   0.9989164501164484],
#  ['true',
#   'positive',
#   0.9999986677814714,
#   6.661092646860978e-07,
#   0.999999333890736],
#  ['true',
#   'negative',
#   0.9979563052877657,
#   0.9989781526438648,
#   0.001021847356099166],
#  ['true',
#   'positive',
#   0.9663114316767173,
#   0.016844284161631008,
#   0.9831557158383483],
#  ['false',
#   'negative',
#   0.7118336944864213,
#   0.8559168472431986,
#   0.14408315275677727],
#  ['true',
#   'positive',
#   0.5329656732704255,
#   0.2335171633647837,
#   0.7664828366352092],
#  ['true',
#   'positive',
#   0.7459883156985706,
#   0.12700584215071598,
#   0.8729941578492866],
#  ['true',
#   'positive',
#   0.9644760289401457,
#   0.017761985529940127,
#   0.9822380144700859],
#  ['false',
#   'positive',
#   0.9999992054723854,
#   3.9726381843193585e-07,
#   0.9999996027362038],
#  ['true',
#   'negative',
#   0.9999961195008602,
#   0.9999980597504596,
#   1.9402495994762897e-06],
#  ['false',
#   'positive',
#   0.9999518006321176,
#   2.409968395885463e-05,
#   0.9999759003160765],
#  ['true',
#   'negative',
#   0.9999997553101097,
#   0.9999998776550644,
#   1.223449547218946e-07],
#  ['true',
#   'negative',
#   0.9149457455968066,
#   0.9574728727983927,
#   0.042527127201585975],
#  ['false',
#   'negative',
#   0.8845335929890615,
#   0.9422667964945337,
#   0.0577332035054722],
#  ['true',
#   'negative',
#   0.9999999978379194,
#   0.9999999989189519,
#   1.0810324535190715e-09],
#  ['true',
#   'negative',
#   0.9999131054521606,
#   0.9999565527261076,
#   4.344727394700928e-05],
#  ['true',
#   'positive',
#   0.9999896923453399,
#   5.153827322919868e-06,
#   0.9999948461726628],
#  ['true', 'negative', 0.999999999999995, 1.0, 5.0252563850192906e-15],
#  ['true', 'negative', 1.0, 1.0, 1.208991760881427e-28],
#  ['true',
#   'positive',
#   0.9999999968565955,
#   1.5716839872244702e-09,
#   0.9999999984282795],
#  ['true',
#   'negative',
#   0.9999573947609439,
#   0.9999786973804554,
#   2.130261951153247e-05],
#  ['true',
#   'negative',
#   0.9999769842124885,
#   0.9999884921062341,
#   1.1507893745571276e-05],
#  ['true',
#   'positive',
#   0.9535214097819906,
#   0.02323929510900749,
#   0.9767607048909981],
#  ['false',
#   'negative',
#   0.999736216455334,
#   0.9998681082276653,
#   0.0001318917723313303],
#  ['true',
#   'positive',
#   0.9933010868695987,
#   0.0033494565651964237,
#   0.9966505434347952],
#  ['true', 'positive', 1.0, 2.4314805022457248e-17, 1.0],
#  ['true', 'negative', 1.0, 1.0, 6.6805482536011515e-18],
#  ['true',
#   'positive',
#   0.9999950787756462,
#   2.460612202840606e-06,
#   0.9999975393878491],
#  ['false',
#   'negative',
#   0.9713948339584101,
#   0.9856974169792073,
#   0.01430258302079719],
#  ['true',
#   'negative',
#   0.9999999999751983,
#   0.9999999999876081,
#   1.240982426571623e-11],
#  ['true', 'negative', 1.0, 1.0, 7.822989761317843e-19],
#  ['true',
#   'negative',
#   0.9999988809596158,
#   0.9999994404798118,
#   5.595201960625372e-07],
#  ['false',
#   'negative',
#   0.9999999999986331,
#   0.9999999999993179,
#   6.848198043849619e-13],
#  ['true',
#   'negative',
#   0.9999999999916134,
#   0.9999999999957936,
#   4.180181681009043e-12],
#  ['false',
#   'positive',
#   0.9994891902353114,
#   0.00025540488235946114,
#   0.9997445951176708],
#  ['true', 'positive', 1.0, 6.031683490226522e-21, 1.0],
#  ['true',
#   'negative',
#   0.9999999948396558,
#   0.9999999974198204,
#   2.580164487929979e-09],
#  ['true',
#   'negative',
#   0.7458952976316944,
#   0.8729476488158203,
#   0.127052351184126],
#  ['true',
#   'negative',
#   0.9326594784967004,
#   0.9663297392483552,
#   0.033670260751654794],
#  ['false',
#   'positive',
#   0.9629751443165718,
#   0.018512427841719796,
#   0.9814875721582916],
#  ['true',
#   'negative',
#   0.9938564197730755,
#   0.9969282098865437,
#   0.003071790113468236],
#  ['true',
#   'negative',
#   0.9999999998057308,
#   0.9999999999029114,
#   9.718058733362862e-11],
#  ['true',
#   'negative',
#   0.999999998595279,
#   0.9999999992976427,
#   7.023637336578789e-10],
#  ['true', 'positive', 1.0, 3.017644729333893e-36, 1.0],
#  ['true',
#   'negative',
#   0.9999999717163084,
#   0.9999999858581533,
#   1.4141844966670288e-08],
#  ['false',
#   'positive',
#   0.41431827686510525,
#   0.29284086156745837,
#   0.7071591384325636],
#  ['false',
#   'negative',
#   0.9999995585158954,
#   0.9999997792579295,
#   2.2074203410731476e-07],
#  ['true',
#   'negative',
#   0.9999999999456766,
#   0.9999999999728288,
#   2.7152326326970392e-11],
#  ['true',
#   'negative',
#   0.9756555472527935,
#   0.9878277736263965,
#   0.012172226373603016],
#  ['true',
#   'negative',
#   0.6607543582022826,
#   0.8303771791011473,
#   0.1696228208988647],
#  ['true',
#   'positive',
#   0.7447732269361897,
#   0.12761338653189322,
#   0.872386613468083],
#  ['true',
#   'positive',
#   0.3552852094438887,
#   0.322357395278049,
#   0.6776426047219377],
#  ['false', 'positive', 0.9999999999999917, 8.31879384920964e-15, 1.0],
#  ['true',
#   'positive',
#   0.999999986486687,
#   6.756676884918055e-09,
#   0.9999999932433639],
#  ['false',
#   'positive',
#   0.998602339431169,
#   0.000698830284437335,
#   0.9993011697156063],
#  ['true',
#   'negative',
#   0.9999999968378931,
#   0.9999999984189571,
#   1.5810640299167169e-09],
#  ['true',
#   'positive',
#   0.5992334956290899,
#   0.20038325218545078,
#   0.7996167478145406],
#  ['true',
#   'negative',
#   0.999998070160483,
#   0.9999990350802471,
#   9.64919764135486e-07],
#  ['true', 'negative', 1.0, 1.0, 1.447928467029058e-20],
#  ['true', 'negative', 0.9999999999999999, 1.0, 6.62321916129157e-17],
#  ['false',
#   'negative',
#   0.9996565055683952,
#   0.999828252784198,
#   0.0001717472158027143],
#  ['true',
#   'negative',
#   0.9999999676009677,
#   0.9999999838004784,
#   1.6199510774151068e-08],
#  ['true', 'negative', 1.0, 1.0, 9.160131945233937e-25],
#  ['true', 'positive', 1.0, 2.911645162662792e-76, 1.0],
#  ['true',
#   'positive',
#   0.9999999999925112,
#   3.7371084928989795e-12,
#   0.9999999999962483],
#  ['false',
#   'negative',
#   0.16216598609971433,
#   0.5810829930498765,
#   0.4189170069501622],
#  ['true',
#   'negative',
#   0.9994168005385639,
#   0.9997084002692852,
#   0.0002915997307213285],
#  ['true',
#   'negative',
#   0.9998736606923329,
#   0.9999368303461695,
#   6.316965383668814e-05],
#  ['true', 'negative', 1.0, 1.0, 5.241259768070805e-28],
#  ['true', 'positive', 0.9999999999999607, 3.9274900841048075e-14, 1.0],
#  ['true',
#   'negative',
#   0.9992333685233495,
#   0.9996166842616796,
#   0.0003833157383300107],
#  ['true', 'positive', 0.9999999999999952, 4.721861846293991e-15, 1.0],
#  ['true',
#   'negative',
#   0.9999986654587144,
#   0.9999993327293689,
#   6.672706545446219e-07],
#  ['true', 'positive', 0.9999999999999981, 1.8722840152902663e-15, 1.0],
#  ['true', 'negative', 0.9999999999999994, 1.0, 5.358917785565665e-16],
#  ['true', 'negative', 1.0, 1.0, 8.048832061029597e-29],
#  ['true', 'positive', 1.0, 1.2422491558779321e-21, 1.0],
#  ['true',
#   'negative',
#   0.9999982387355355,
#   0.9999991193677614,
#   8.8063222588268e-07],
#  ['false',
#   'positive',
#   0.9999999637307448,
#   1.8134613006568743e-08,
#   0.9999999818653579],
#  ['true',
#   'positive',
#   0.9999880640520793,
#   5.9679739323856915e-06,
#   0.9999940320260117],
#  ['true',
#   'negative',
#   0.9999530724802456,
#   0.999976536240112,
#   2.3463759866379137e-05],
#  ['true',
#   'negative',
#   0.07574100386710253,
#   0.5378705019335637,
#   0.46212949806646114],
#  ['false',
#   'positive',
#   0.99634102654442,
#   0.0018294867277966929,
#   0.9981705132722167],
#  ['true',
#   'negative',
#   0.999999999998275,
#   0.9999999999991473,
#   8.723152737031304e-13],
#  ['false',
#   'negative',
#   0.9989371393917233,
#   0.9994685696958606,
#   0.0005314303041372432],
#  ['true',
#   'positive',
#   0.9999718285417283,
#   1.4085729122214404e-05,
#   0.9999859142708505],
#  ['true', 'negative', 1.0, 1.0, 1.6615375255896268e-20],
#  ['false',
#   'negative',
#   0.9999992939338946,
#   0.9999996469669609,
#   3.5303306621797004e-07],
#  ['true',
#   'negative',
#   0.9967836117655344,
#   0.9983918058827732,
#   0.0016081941172387524],
#  ['true',
#   'negative',
#   0.9998356543537493,
#   0.9999178271768729,
#   8.217282312360302e-05],
#  ['true', 'negative', 0.9999999999999997, 1.0, 3.800667638067199e-16],
#  ['true',
#   'positive',
#   0.9999999991034342,
#   4.4829866342067175e-10,
#   0.9999999995517328],
#  ['false',
#   'negative',
#   0.1222420724592379,
#   0.5611210362296221,
#   0.43887896377038416],
#  ['true', 'positive', 1.0, 4.99884192510805e-18, 1.0],
#  ['true',
#   'negative',
#   0.9999999970159283,
#   0.9999999985079739,
#   1.4920455445448858e-09],
#  ['true', 'negative', 0.48931898581296, 0.7446594929064417, 0.2553405070934817],
#  ['false',
#   'positive',
#   0.9909994842563947,
#   0.00450025787181345,
#   0.9954997421282081],
#  ['true',
#   'negative',
#   0.9999999543666611,
#   0.9999999771833361,
#   2.2816674949054877e-08],
#  ['true',
#   'positive',
#   0.9010270873891127,
#   0.04948645630545701,
#   0.9505135436945698],
#  ['false',
#   'negative',
#   0.9532992439309763,
#   0.9766496219655632,
#   0.023350378034586842],
#  ['true',
#   'positive',
#   0.9999999864114486,
#   6.794284967031686e-09,
#   0.9999999932057335],
#  ['true',
#   'negative',
#   0.9999596079910578,
#   0.9999798039955173,
#   2.0196004459548488e-05],
#  ['true',
#   'negative',
#   0.9998403374191411,
#   0.9999201687095672,
#   7.983129042609454e-05],
#  ['true',
#   'negative',
#   0.9999991911979143,
#   0.999999595598947,
#   4.04401032796138e-07],
#  ['true',
#   'negative',
#   0.9999995106469222,
#   0.9999997553234452,
#   2.446765230573963e-07],
#  ['true',
#   'positive',
#   0.9999997753033228,
#   1.1234833772029356e-07,
#   0.9999998876516606],
#  ['false',
#   'negative',
#   0.9999863702856228,
#   0.9999931851428137,
#   6.814857190910209e-06],
#  ['true',
#   'negative',
#   0.5562920459486418,
#   0.7781460229743191,
#   0.22185397702567736],
#  ['true',
#   'negative',
#   0.9999882851065589,
#   0.9999941425532934,
#   5.857446734492015e-06],
#  ['true',
#   'negative',
#   0.999999999653712,
#   0.999999999826855,
#   1.7314297474335489e-10],
#  ['true',
#   'positive',
#   0.999723155610358,
#   0.00013842219481285484,
#   0.9998615778051708],
#  ['true',
#   'negative',
#   0.9999999999359231,
#   0.9999999999679403,
#   3.20171807803565e-11],
#  ['true', 'negative', 1.0, 1.0, 3.9704721403384454e-24],
#  ['true',
#   'negative',
#   0.999999906890595,
#   0.9999999534452979,
#   4.6554702921401586e-08],
#  ['true', 'negative', 1.0, 1.0, 3.6859495968543447e-20],
#  ['false',
#   'negative',
#   0.9999979694911146,
#   0.9999989847455633,
#   1.0152544486061342e-06],
#  ['true',
#   'positive',
#   0.9999999995180003,
#   2.409835790384453e-10,
#   0.9999999997589839],
#  ['true',
#   'positive',
#   0.981725271392649,
#   0.009137364303677648,
#   0.9908626356963266],
#  ['true',
#   'negative',
#   0.9999999931923583,
#   0.9999999965962161,
#   3.4038577727149053e-09],
#  ['true',
#   'negative',
#   0.9999728443106561,
#   0.9999864221552823,
#   1.3577844626144782e-05],
#  ['true',
#   'negative',
#   0.9999997166596635,
#   0.9999998583298393,
#   1.416701758237951e-07],
#  ['true',
#   'positive',
#   0.9552035192570717,
#   0.02239824037146278,
#   0.9776017596285345],
#  ['true',
#   'positive',
#   0.6197985330236422,
#   0.1901007334881834,
#   0.8098992665118256],
#  ['true',
#   'positive',
#   0.999998212945915,
#   8.935270419965175e-07,
#   0.999999106472957],
#  ['false',
#   'negative',
#   0.9999953783739204,
#   0.9999976891869534,
#   2.3108130329959123e-06],
#  ['true',
#   'negative',
#   0.9999999999995597,
#   0.9999999999997726,
#   2.128970876682022e-13],
#  ['true', 'negative', 1.0, 1.0, 1.029605724876328e-21],
#  ['false',
#   'positive',
#   0.9994858705401878,
#   0.00025706472987444326,
#   0.9997429352700622],
#  ['true',
#   'positive',
#   0.9999999999870424,
#   6.477494747040549e-12,
#   0.9999999999935199],
#  ['false',
#   'negative',
#   0.32251312062652876,
#   0.6612565603132532,
#   0.33874343968672443],
#  ['true',
#   'negative',
#   0.9999983603530579,
#   0.9999991801765254,
#   8.198234675110321e-07],
#  ['true', 'negative', 0.9999999999999455, 1.0, 5.450239731124895e-14],
#  ['true',
#   'negative',
#   0.9999998723337818,
#   0.999999936166889,
#   6.383310707886142e-08],
#  ['true',
#   'positive',
#   0.9999999999990066,
#   5.386779892556258e-13,
#   0.9999999999995453],
#  ['true',
#   'positive',
#   0.9832398595084939,
#   0.008380070245752038,
#   0.991619929754246],
#  ['true',
#   'positive',
#   0.9806493639963632,
#   0.009675318001825051,
#   0.9903246819981882],
#  ['true',
#   'negative',
#   0.8433358829659702,
#   0.921667941482957,
#   0.07833205851698687],
#  ['false',
#   'negative',
#   0.9999802300256583,
#   0.9999901150128209,
#   9.884987162635168e-06],
#  ['true',
#   'positive',
#   0.9999999999900129,
#   4.984916977158913e-12,
#   0.9999999999949978],
#  ['true',
#   'positive',
#   0.9999998142928047,
#   9.285358863549177e-08,
#   0.9999999071463933],
#  ['true',
#   'positive',
#   0.6866612011832423,
#   0.15666939940839203,
#   0.8433306005916343],
#  ['true',
#   'negative',
#   0.9999999999994387,
#   0.9999999999997158,
#   2.7709534320807274e-13],
#  ['false',
#   'negative',
#   0.9999997820113654,
#   0.9999998910057062,
#   1.0899434074259644e-07],
#  ['true',
#   'negative',
#   0.990374640792727,
#   0.9951873203963588,
#   0.004812679603631893],
#  ['true',
#   'positive',
#   0.99999998672403,
#   6.638022857148846e-09,
#   0.9999999933620529],
#  ['true', 'positive', 1.0, 2.5933600016912628e-17, 1.0],
#  ['true',
#   'negative',
#   0.922905055837295,
#   0.9614525279186255,
#   0.03854747208133043],
#  ['true',
#   'positive',
#   0.9133077035777942,
#   0.04334614821111413,
#   0.9566538517889084],
#  ['true',
#   'negative',
#   0.9999981716706519,
#   0.9999990858353471,
#   9.141646953015916e-07],
#  ['false',
#   'negative',
#   0.9977601205278049,
#   0.9988800602638949,
#   0.0011199397360898723],
#  ['false',
#   'negative',
#   0.9441928372068576,
#   0.9720964186034499,
#   0.02790358139659221],
#  ['true',
#   'negative',
#   0.9997864064121029,
#   0.9998932032060264,
#   0.00010679679392348435],
#  ['true',
#   'positive',
#   0.9999999999747066,
#   1.267415844652458e-11,
#   0.9999999999873808],
#  ['false',
#   'negative',
#   0.9880266587960156,
#   0.994013329398006,
#   0.005986670601990384],
#  ['true',
#   'positive',
#   0.9995870499177488,
#   0.00020647504113514498,
#   0.999793524958884],
#  ['true', 'negative', 0.9999999999999996, 1.0, 4.425893664572899e-16],
#  ['true',
#   'negative',
#   0.9999960874742183,
#   0.9999980437371313,
#   1.956262913046684e-06],
#  ['true',
#   'negative',
#   0.9999893228437506,
#   0.9999946614218768,
#   5.338578126125766e-06],
#  ['true', 'negative', 0.9999999999999992, 1.0, 7.464828293455014e-16],
#  ['false',
#   'positive',
#   0.8350274179708261,
#   0.0824862910145941,
#   0.9175137089854203],
#  ['false',
#   'negative',
#   0.981900665231713,
#   0.9909503326158589,
#   0.009049667384145792],
#  ['true', 'negative', 0.9999999999999979, 1.0, 2.1487115733593522e-15],
#  ['false',
#   'negative',
#   0.5496597008776074,
#   0.7748298504388036,
#   0.22517014956119624],
#  ['true',
#   'negative',
#   0.9992471038069269,
#   0.9996235519034623,
#   0.000376448096535321],
#  ['true',
#   'positive',
#   0.9745549939539786,
#   0.01272250302302313,
#   0.9872774969770017],
#  ['false',
#   'negative',
#   0.9999999352496749,
#   0.9999999676248313,
#   3.237515640960069e-08],
#  ['true',
#   'positive',
#   0.9999999999990657,
#   4.794869418064503e-13,
#   0.9999999999995453],
#  ['true',
#   'negative',
#   0.9999999999997686,
#   0.9999999999998863,
#   1.1767250024618958e-13],
#  ['true',
#   'positive',
#   0.9999997789398521,
#   1.1053005860974951e-07,
#   0.9999998894699108],
#  ['false',
#   'negative',
#   0.0722729110018544,
#   0.5361364555009251,
#   0.46386354449907075],
#  ['true',
#   'negative',
#   0.9999996088803067,
#   0.9999998044401273,
#   1.9555982059042262e-07],
#  ['true',
#   'negative',
#   0.999999999864953,
#   0.99999999993247,
#   6.751703203648568e-11],
#  ['false',
#   'negative',
#   0.959144792521473,
#   0.9795723962607256,
#   0.0204276037392526],
#  ['false',
#   'negative',
#   0.9723932243410747,
#   0.9861966121705381,
#   0.013803387829463457],
#  ['true', 'negative', 1.0, 1.0, 2.9820463603358634e-17],
#  ['true', 'negative', 1.0, 1.0, 3.908853359627853e-22],
#  ['true',
#   'negative',
#   0.9999999999913523,
#   0.9999999999956799,
#   4.327680885506204e-12],
#  ['true',
#   'negative',
#   0.9999871896936957,
#   0.9999935948468345,
#   6.405153138735244e-06],
#  ['true',
#   'negative',
#   0.9999999994758828,
#   0.9999999997379518,
#   2.6206902327939045e-10],
#  ['true',
#   'negative',
#   0.9999946990787211,
#   0.999997349539387,
#   2.650460665946528e-06],
#  ['false',
#   'negative',
#   0.7838035450225214,
#   0.8919017725112572,
#   0.10809822748873583],
#  ['true',
#   'negative',
#   0.3756992971642576,
#   0.687849648582144,
#   0.31215035141788644],
#  ['true',
#   'negative',
#   0.9999999913994098,
#   0.9999999956997101,
#   4.300300298070434e-09],
#  ['true', 'negative', 1.0, 1.0, 5.839668146294078e-23],
#  ['true',
#   'negative',
#   0.9999999999629554,
#   0.999999999981469,
#   1.8513669235135977e-11],
#  ['true',
#   'positive',
#   0.9956730644722379,
#   0.0021634677639090667,
#   0.997836532236147],
#  ['false',
#   'negative',
#   0.11916241528655985,
#   0.5595812076432848,
#   0.44041879235672493],
#  ['true',
#   'negative',
#   0.9999999999969168,
#   0.9999999999984652,
#   1.5483901633481363e-12],
#  ['true', 'negative', 1.0, 1.0, 1.7102604259603436e-22],
#  ['true',
#   'negative',
#   0.9999854297660299,
#   0.9999927148830259,
#   7.285116995945047e-06],
#  ['true',
#   'positive',
#   0.9999999993151791,
#   3.423961596574261e-10,
#   0.9999999996575752],
#  ['true',
#   'positive',
#   0.9999999998924767,
#   5.37494625128099e-11,
#   0.9999999999462261],
#  ['true',
#   'positive',
#   0.9999999644906282,
#   1.775467111176869e-08,
#   0.9999999822452993],
#  ['true', 'positive', 1.0, 1.124194934277294e-30, 1.0],
#  ['true',
#   'negative',
#   0.9999991480552097,
#   0.9999995740276174,
#   4.25972407735829e-07],
#  ['true',
#   'negative',
#   0.9997705007314381,
#   0.9998852503657205,
#   0.00011474963428233852],
#  ['true',
#   'positive',
#   0.9960948362308395,
#   0.001952581884582625,
#   0.9980474181154221],
#  ['true',
#   'positive',
#   0.9999983150608043,
#   8.42469606050387e-07,
#   0.9999991575304104],
#  ['true',
#   'positive',
#   0.5711895914063119,
#   0.21440520429684257,
#   0.7855947957031545],
#  ['true',
#   'negative',
#   0.10131795077058914,
#   0.5506589753852864,
#   0.44934102461469727],
#  ['true', 'positive', 1.0, 2.0572357620858175e-20, 1.0],
#  ['true',
#   'negative',
#   0.9999981907811508,
#   0.999999095390575,
#   9.046094241259851e-07],
#  ['false',
#   'negative',
#   0.9997985869648669,
#   0.9998992934824417,
#   0.00010070651757481544],
#  ['true',
#   'positive',
#   0.9999991369458505,
#   4.315270872356443e-07,
#   0.9999995684729378],
#  ['true',
#   'positive',
#   0.9999972987725704,
#   1.3506137029312553e-06,
#   0.9999986493862733],
#  ['true', 'negative', 0.9999999999999631, 1.0, 3.6887304279590556e-14],
#  ['true',
#   'negative',
#   0.9999999985366488,
#   0.9999999992683115,
#   7.316627422265339e-10],
#  ['false',
#   'negative',
#   0.9935713576173932,
#   0.9967856788086754,
#   0.0032143211912821546],
#  ['false',
#   'negative',
#   0.9999923088572457,
#   0.9999961544286339,
#   3.845571388248758e-06],
#  ['true',
#   'negative',
#   0.9999999036078974,
#   0.9999999518039442,
#   4.819604680568468e-08],
#  ['true',
#   'positive',
#   0.9998567406502745,
#   7.162967484718643e-05,
#   0.9999283703251217],
#  ['false',
#   'negative',
#   0.9999998301041131,
#   0.9999999150520615,
#   8.494794845283263e-08],
#  ['false',
#   'negative',
#   0.9979909265290112,
#   0.9989954632645137,
#   0.0010045367355025086],
#  ['true', 'positive', 1.0, 6.293660058102167e-24, 1.0],
#  ['true',
#   'positive',
#   0.9191612129869259,
#   0.04041939350653744,
#   0.9595806064934633],
#  ['true', 'negative', 1.0, 1.0, 1.4322616640545622e-24],
#  ['true', 'negative', 1.0, 1.0, 2.7184759991206708e-17],
#  ['false',
#   'negative',
#   0.999999987836635,
#   0.9999999939183226,
#   6.081687615946165e-09],
#  ['true',
#   'negative',
#   0.9993149311606104,
#   0.9996574655802887,
#   0.000342534419678269],
#  ['true',
#   'positive',
#   0.9569186345180543,
#   0.02154068274098043,
#   0.9784593172590347],
#  ['false',
#   'positive',
#   0.9981027807474426,
#   0.0009486096263053558,
#   0.999051390373748],
#  ['true',
#   'positive',
#   0.9999991383030102,
#   4.3084852400720737e-07,
#   0.9999995691515342],
#  ['true',
#   'negative',
#   0.9999999962872566,
#   0.9999999981436076,
#   1.856351116515161e-09],
#  ['true',
#   'negative',
#   0.999999418087395,
#   0.9999997090437059,
#   2.90956310975798e-07],
#  ['true', 'positive', 1.0, 1.2179964641211901e-21, 1.0],
#  ['false', 'negative', 1.0, 1.0, 1.540570432450943e-23],
#  ['true',
#   'negative',
#   0.9999999477058873,
#   0.9999999738529372,
#   2.614704980342622e-08],
#  ['true',
#   'negative',
#   0.9999999955029862,
#   0.9999999977515017,
#   2.2485154319424047e-09],
#  ['false',
#   'negative',
#   0.6804519955088159,
#   0.8402259977544156,
#   0.1597740022455998],
#  ['true',
#   'negative',
#   0.9999950744153825,
#   0.9999975372076819,
#   2.46279229942267e-06],
#  ['false',
#   'negative',
#   0.9999986698835353,
#   0.9999993349417702,
#   6.650582349815578e-07],
#  ['true',
#   'positive',
#   0.9887227951322332,
#   0.005638602433856198,
#   0.9943613975660893],
#  ['true',
#   'negative',
#   0.9999999900684352,
#   0.9999999950342158,
#   4.965780611087303e-09],
#  ['false',
#   'positive',
#   0.7130269672254368,
#   0.14348651638727639,
#   0.8565134836127132],
#  ['true',
#   'positive',
#   0.9999999963785817,
#   1.8107280610484029e-09,
#   0.9999999981893097],
#  ['true',
#   'positive',
#   0.9988296874118228,
#   0.0005851562940750089,
#   0.9994148437058977],
#  ['false',
#   'positive',
#   0.9999809405961312,
#   9.529701945868859e-06,
#   0.9999904702980771],
#  ['true', 'positive', 0.9999999999999519, 4.803658056238176e-14, 1.0],
#  ['true',
# ...
#  ['true',
#   'negative',
#   0.9999809951989674,
#   0.999990497599484,
#   9.50240051657363e-06],
#  ['true',
#   'negative',
#   0.9999999999526769,
#   0.9999999999763531,
#   2.3676249352813617e-11],
#  ['true', 'positive', 1.0, 4.697415810024443e-19, 1.0],
#  ['true', 'negative', 1.0, 1.0, 2.489988515797076e-60],
#  ['false',
#   'negative',
#   0.8637816718405508,
#   0.9318908359202726,
#   0.06810916407972181],
#  ['true',
#   'negative',
#   0.9999999997636595,
#   0.9999999998818225,
#   1.1816303053237433e-10],
#  ['true',
#   'positive',
#   0.9923273551333635,
#   0.0038363224333231877,
#   0.9961636775666867],
#  ['true',
#   'negative',
#   0.9999977939649664,
#   0.999998896982487,
#   1.1030175206311724e-06],
#  ['true',
#   'negative',
#   0.9999999999371528,
#   0.9999999999685656,
#   3.1412734874352906e-11],
#  ['true',
#   'negative',
#   0.9999398632815945,
#   0.999969931640792,
#   3.0068359197517678e-05],
#  ['true',
#   'positive',
#   0.9742925565667223,
#   0.012853721716633413,
#   0.9871462782833558],
#  ['true',
#   'negative',
#   0.9999998945626369,
#   0.9999999472813116,
#   5.27186746010729e-08],
#  ['true',
#   'positive',
#   0.9999528783033024,
#   2.3560848372967117e-05,
#   0.9999764391516753],
#  ['true',
#   'positive',
#   0.9999962853242127,
#   1.8573379002457097e-06,
#   0.999998142662113],
#  ['false',
#   'negative',
#   0.9923819249915522,
#   0.9961909624957784,
#   0.0038090375042262657],
#  ['true', 'positive', 0.9999999999999998, 1.8802795483981659e-16, 1.0],
#  ['true',
#   'positive',
#   0.9999999971713682,
#   1.4143674771895597e-09,
#   0.9999999985857357],
#  ['true',
#   'positive',
#   0.9999893816832349,
#   5.309158379218391e-06,
#   0.9999946908416142],
#  ['true', 'positive', 1.0, 2.6536693538533173e-49, 1.0],
#  ['true',
#   'positive',
#   0.9999999861146996,
#   6.942672537034072e-09,
#   0.9999999930573722],
#  ['true', 'negative', 1.0, 1.0, 3.930062371141843e-20],
#  ['false',
#   'negative',
#   0.9999753687882521,
#   0.9999876843941223,
#   1.2315605870213727e-05],
#  ['false',
#   'negative',
#   0.8673676118333042,
#   0.933683805916648,
#   0.0663161940833438],
#  ['true',
#   'positive',
#   0.007096720020756397,
#   0.49645163998962244,
#   0.5035483600103788],
#  ['true',
#   'negative',
#   0.14091103014736456,
#   0.5704555150736775,
#   0.429544484926313],
#  ['true',
#   'positive',
#   0.9999201303642374,
#   3.993481788743331e-05,
#   0.9999600651821249],
#  ['true',
#   'positive',
#   0.039417299882519186,
#   0.4802913500587471,
#   0.5197086499412663],
#  ['true',
#   'positive',
#   0.9969785723352244,
#   0.0015107138323917167,
#   0.9984892861676161],
#  ['true',
#   'negative',
#   0.999618285746166,
#   0.9998091428730705,
#   0.00019085712690460787],
#  ['true',
#   'positive',
#   0.9999999688210599,
#   1.5589462064854583e-08,
#   0.999999984410522],
#  ['true', 'positive', 1.0, 4.553005987960704e-19, 1.0],
#  ['true',
#   'negative',
#   0.9999068532775336,
#   0.9999534266387402,
#   4.657336120665867e-05],
#  ['true',
#   'negative',
#   0.9981991627381603,
#   0.9990995813690701,
#   0.0009004186309096967],
#  ['false',
#   'negative',
#   0.8369418484406306,
#   0.9184709242203252,
#   0.0815290757796946],
#  ['true',
#   'negative',
#   0.9999880918067425,
#   0.9999940459033402,
#   5.954096597693209e-06],
#  ['true',
#   'positive',
#   0.9999999153716488,
#   4.231416798520649e-08,
#   0.9999999576858167],
#  ['false',
#   'negative',
#   0.9944758367444373,
#   0.9972379183721907,
#   0.002762081627753426],
#  ['true',
#   'negative',
#   0.9999993093576627,
#   0.9999996546787911,
#   3.4532112845064386e-07],
#  ['true',
#   'positive',
#   0.9999998114949689,
#   9.425250798361847e-08,
#   0.9999999057474769],
#  ['false',
#   'positive',
#   0.9989361454689192,
#   0.0005319272655502204,
#   0.9994680727344694],
#  ['true', 'positive', 1.0, 1.5889603702189196e-40, 1.0],
#  ['true',
#   'negative',
#   0.9999999999950402,
#   0.9999999999974989,
#   2.458731586887026e-12],
#  ['true',
#   'negative',
#   0.9983764378069389,
#   0.9991882189034693,
#   0.0008117810965304926],
#  ['false',
#   'negative',
#   0.5191889078409684,
#   0.7595944539205,
#   0.24040554607953157],
#  ['false',
#   'positive',
#   0.9999999997002754,
#   1.4988532168147054e-10,
#   0.9999999998501607],
#  ['true',
#   'negative',
#   0.9998318889177871,
#   0.9999159444588951,
#   8.405554110802195e-05],
#  ['true',
#   'negative',
#   0.997618677858952,
#   0.9988093389294869,
#   0.0011906610705348939],
#  ['false',
#   'negative',
#   0.16778444688765348,
#   0.5838922234438241,
#   0.4161077765561706],
#  ['true',
#   'negative',
#   0.9999999673101374,
#   0.9999999836550729,
#   1.6344935514219658e-08],
#  ['true',
#   'negative',
#   0.9999999999995947,
#   0.9999999999997726,
#   1.7801601521336857e-13],
#  ['true',
#   'negative',
#   0.9999993708174012,
#   0.9999996854086743,
#   3.1459127315941967e-07],
#  ['false',
#   'negative',
#   0.9879470656489011,
#   0.9939735328244547,
#   0.006026467175553529],
#  ['true',
#   'negative',
#   0.9999999209971802,
#   0.9999999604985995,
#   3.950141930915034e-08],
#  ['true',
#   'positive',
#   0.8001016915303272,
#   0.09994915423483546,
#   0.9000508457651626],
#  ['false',
#   'positive',
#   0.9999493402383207,
#   2.5329880834421235e-05,
#   0.9999746701191551],
#  ['true',
#   'positive',
#   0.6266865661704661,
#   0.18665671691473867,
#   0.8133432830852049],
#  ['true',
#   'negative',
#   0.7027787763079585,
#   0.8513893881539935,
#   0.14861061184603502],
#  ['true',
#   'negative',
#   0.9999999999852123,
#   0.9999999999926104,
#   7.398107579113995e-12],
#  ['true',
#   'positive',
#   0.48076769188259616,
#   0.25961615405870486,
#   0.740383845941301],
#  ['true',
#   'negative',
#   0.9998974237348858,
#   0.9999487118674422,
#   5.128813255642503e-05],
#  ['false',
#   'positive',
#   0.9999999182023451,
#   4.089881584115147e-08,
#   0.999999959101161],
#  ['true',
#   'negative',
#   0.9999999939624502,
#   0.9999999969812166,
#   3.0187663293107674e-09],
#  ['true',
#   'positive',
#   0.999999999914445,
#   4.280870326978819e-11,
#   0.9999999999572537],
#  ['false',
#   'negative',
#   0.9986122156359148,
#   0.999306107817973,
#   0.0006938921820581248],
#  ['false',
#   'negative',
#   0.9998597132127555,
#   0.9999298566063796,
#   7.014339362406354e-05],
#  ['true',
#   'positive',
#   0.5444122669883517,
#   0.22779386650584957,
#   0.7722061334942012],
#  ['true', 'positive', 1.0, 2.135292766394033e-22, 1.0],
#  ['true', 'positive', 0.9999999999999846, 1.5466513805980855e-14, 1.0],
#  ['true',
#   'positive',
#   0.9984871588147276,
#   0.0007564205926382299,
#   0.9992435794073659],
#  ['true',
#   'negative',
#   0.9999999999990846,
#   0.9999999999995453,
#   4.606011406471212e-13],
#  ['true',
#   'positive',
#   0.9999927300007443,
#   3.634999624917539e-06,
#   0.9999963650003693],
#  ['true',
#   'positive',
#   0.9037962389201072,
#   0.048101880539956586,
#   0.9518981194600638],
#  ['true', 'negative', 1.0, 1.0, 8.478177016263223e-18],
#  ['true',
#   'positive',
#   0.999832337785805,
#   8.383110708188019e-05,
#   0.9999161688928869],
#  ['true',
#   'negative',
#   0.9999999999632087,
#   0.9999999999815827,
#   1.8374129157136327e-11],
#  ['false',
#   'positive',
#   0.9999999998468092,
#   7.65659184681308e-11,
#   0.9999999999233751],
#  ['false',
#   'positive',
#   0.35518679376399065,
#   0.3224066031180124,
#   0.677593396882003],
#  ['true',
#   'positive',
#   0.9999027488303062,
#   4.8625584830931746e-05,
#   0.9999513744151372],
#  ['false',
#   'positive',
#   0.9999993016333639,
#   3.491833161087091e-07,
#   0.9999996508166801],
#  ['true', 'positive', 1.0, 6.181990339111523e-29, 1.0],
#  ['true',
#   'negative',
#   0.9999979619200333,
#   0.9999989809600228,
#   1.0190399895050659e-06],
#  ['false',
#   'negative',
#   0.8769718147419953,
#   0.9384859073709753,
#   0.06151409262898001],
#  ['true',
#   'negative',
#   0.9999998022428719,
#   0.9999999011214462,
#   9.88785743820028e-08],
#  ['true', 'negative', 1.0, 1.0, 1.7336432536687264e-17],
#  ['true',
#   'negative',
#   0.9999999999533872,
#   0.9999999999766942,
#   2.3307047529756588e-11],
#  ['true',
#   'positive',
#   0.999709232559231,
#   0.00014538372037459048,
#   0.9998546162796056],
#  ['true',
#   'negative',
#   0.999745319712856,
#   0.9998726598564226,
#   0.0001273401435666226],
#  ['true', 'positive', 1.0, 1.1099670680881817e-37, 1.0],
#  ['true',
#   'negative',
#   0.9998420842220705,
#   0.9999210421110429,
#   7.895788897240221e-05],
#  ['true',
#   'positive',
#   0.9969415324875401,
#   0.0015292337562412966,
#   0.9984707662437814],
#  ['true', 'negative', 1.0, 1.0, 2.898866414712798e-26],
#  ['true',
#   'negative',
#   0.9536047426716511,
#   0.9768023713358519,
#   0.02319762866420081],
#  ['true',
#   'negative',
#   0.8021106647356535,
#   0.901055332367828,
#   0.09894466763217448],
#  ['true',
#   'negative',
#   0.9999766952130181,
#   0.9999883476065081,
#   1.1652393490008161e-05],
#  ['true', 'negative', 1.0, 1.0, 7.27828975164914e-19],
#  ['true', 'positive', 1.0, 1.5479419917659135e-48, 1.0],
#  ['true',
#   'positive',
#   0.9999999791143375,
#   1.0442844379097242e-08,
#   0.9999999895571818],
#  ['true',
#   'negative',
#   0.9999994023365819,
#   0.99999970116828,
#   2.9883169805712295e-07],
#  ['true',
#   'positive',
#   0.9999999997114848,
#   1.442465857359209e-10,
#   0.9999999998557314],
#  ['true',
#   'positive',
#   0.9931894752691017,
#   0.0034052623654500934,
#   0.9965947376345519],
#  ['false',
#   'positive',
#   0.9533926167054106,
#   0.023303691647296603,
#   0.9766963083527073],
#  ['true',
#   'positive',
#   0.9999741073401047,
#   1.2946329909752186e-05,
#   0.9999870536700145],
#  ['true', 'negative', 1.0, 1.0, 1.7141939751297182e-39],
#  ['true',
#   'positive',
#   0.9999996315607858,
#   1.8421960142061618e-07,
#   0.9999998157803872],
#  ['true', 'positive', 1.0, 9.275446099023404e-26, 1.0],
#  ['true', 'positive', 0.9999999999999917, 8.323921536120594e-15, 1.0],
#  ['true', 'negative', 0.9999999999999687, 1.0, 3.1363580082955077e-14],
#  ['true',
#   'negative',
#   0.9999999963107333,
#   0.9999999981553742,
#   1.8446409334640628e-09],
#  ['true', 'positive', 1.0, 5.929332389355477e-55, 1.0],
#  ['false',
#   'negative',
#   0.9334669920462222,
#   0.9667334960231109,
#   0.03326650397688869],
#  ['true',
#   'negative',
#   0.9999687595438034,
#   0.9999843797718992,
#   1.562022809591709e-05],
#  ['true',
#   'negative',
#   0.9999999996280311,
#   0.9999999998140083,
#   1.8597723981934466e-10],
#  ['true', 'negative', 1.0, 1.0, 3.3174762277019366e-23],
#  ['true',
#   'negative',
#   0.9999999999996494,
#   0.9999999999997726,
#   1.2323629741119688e-13],
#  ['true', 'negative', 1.0, 1.0, 6.255191924589529e-20],
#  ['true',
#   'negative',
#   0.9999993876149369,
#   0.9999996938074573,
#   3.061925204852102e-07],
#  ['true',
#   'negative',
#   0.9998868815585694,
#   0.9999434407793207,
#   5.655922075135235e-05],
#  ['true',
#   'positive',
#   0.9999966744931157,
#   1.6627534546305924e-06,
#   0.9999983372465703],
#  ['true',
#   'positive',
#   0.9999999999974861,
#   1.2632988926192025e-12,
#   0.9999999999987494],
#  ['true',
#   'negative',
#   0.9997956151895963,
#   0.9998978075947996,
#   0.00010219240520332806],
#  ['false',
#   'positive',
#   0.9995217875592353,
#   0.0002391062203743164,
#   0.9997608937796095],
#  ['true', 'negative', 1.0, 1.0, 2.0304781951559917e-19],
#  ['true',
#   'positive',
#   0.9999177318754479,
#   4.113406226564341e-05,
#   0.9999588659377135],
#  ['true',
#   'negative',
#   0.9999999999972529,
#   0.9999999999986358,
#   1.382935084109169e-12],
#  ['true', 'negative', 1.0, 1.0, 1.6577161918772932e-21],
#  ['true',
#   'negative',
#   0.9999317273835182,
#   0.9999658636917395,
#   3.413630822119227e-05],
#  ['true',
#   'positive',
#   0.45157018014077965,
#   0.2742149099296143,
#   0.7257850900703939],
#  ['false',
#   'negative',
#   0.9877691110477846,
#   0.9938845555239044,
#   0.006115444476119769],
#  ['true', 'positive', 1.0, 1.8359232023780744e-31, 1.0],
#  ['false',
#   'negative',
#   0.9641031312270196,
#   0.982051565613511,
#   0.01794843438649141],
#  ['true',
#   'negative',
#   0.9999999994043174,
#   0.9999999997021405,
#   2.9782307445441944e-10],
#  ['true', 'positive', 1.0, 2.6304893941871556e-29, 1.0],
#  ['false',
#   'negative',
#   0.9977179040481131,
#   0.9988589520240632,
#   0.001141047975950057],
#  ['true',
#   'negative',
#   0.9971864017615718,
#   0.9985932008807866,
#   0.0014067991192147663],
#  ['true', 'negative', 0.9999999999999999, 1.0, 1.5612669262839137e-16],
#  ['false', 'positive', 1.0, 4.141893975998024e-22, 1.0],
#  ['true', 'positive', 1.0, 2.6832071455058846e-36, 1.0],
#  ['true',
#   'negative',
#   0.9999999996181507,
#   0.999999999809063,
#   1.9091233050507258e-10],
#  ['false',
#   'negative',
#   0.9997229919638095,
#   0.9998614959819024,
#   0.00013850401809286113],
#  ['true',
#   'positive',
#   0.9999999999990936,
#   4.515851449770475e-13,
#   0.9999999999995453],
#  ['true',
#   'positive',
#   0.3534868541568251,
#   0.3232565729215857,
#   0.6767434270784108],
#  ['true',
#   'positive',
#   0.9999999999975018,
#   1.2476871925805164e-12,
#   0.9999999999987494],
#  ['true',
#   'positive',
#   0.9412096610525652,
#   0.029395169473722907,
#   0.9706048305262881],
#  ['true', 'negative', 0.9999999999999999, 1.0, 1.124499789178278e-16],
#  ['false',
#   'negative',
#   0.99866121282042,
#   0.9993306064102154,
#   0.0006693935897954656],
#  ['true',
#   'positive',
#   0.9999998959324337,
#   5.203378416925218e-08,
#   0.9999999479662178],
#  ['true',
#   'negative',
#   0.9999999999897571,
#   0.9999999999948841,
#   5.126961929239035e-12],
#  ['true',
#   'positive',
#   0.41551285936639587,
#   0.29224357031678433,
#   0.7077564296831802],
#  ['true',
#   'negative',
#   0.9895352318122994,
#   0.9947676159061364,
#   0.005232384093836936],
#  ['true',
#   'negative',
#   0.999999941544537,
#   0.9999999707722513,
#   2.9227714332903755e-08],
#  ['false',
#   'negative',
#   0.9933002138024527,
#   0.9966501069012439,
#   0.0033498930987911706],
#  ['true',
#   'positive',
#   0.9999999736335614,
#   1.3183199306552055e-08,
#   0.9999999868167607],
#  ['false',
#   'negative',
#   0.9999916239580897,
#   0.9999958119790494,
#   4.1880209596759466e-06],
#  ['false',
#   'negative',
#   0.999947170594988,
#   0.9999735852975086,
#   2.6414702520533722e-05],
#  ['true', 'positive', 0.9999999999999996, 3.887953755676112e-16, 1.0],
#  ['false',
#   'positive',
#   0.98461147777067,
#   0.007694261114685149,
#   0.9923057388853552],
#  ['true', 'negative', 0.9999999999999104, 1.0, 8.963797451701411e-14],
#  ['true',
#   'negative',
#   0.999999999999859,
#   0.9999999999999432,
#   8.413167854915674e-14],
#  ['true', 'positive', 1.0, 2.4695165379326847e-18, 1.0],
#  ['true',
#   'negative',
#   0.9746337680524857,
#   0.9873168840262475,
#   0.012683115973761781],
#  ['true',
#   'negative',
#   0.9999999828068974,
#   0.9999999914034561,
#   8.596558668939895e-09],
#  ['true',
#   'positive',
#   0.9985146387554515,
#   0.0007426806222637816,
#   0.9992573193777153],
#  ['true',
#   'positive',
#   0.999986601400642,
#   6.699299684417749e-06,
#   0.9999933007003264],
#  ['true',
#   'negative',
#   0.9796447771263705,
#   0.989822388563181,
#   0.010177611436810464],
#  ['true', 'negative', 1.0, 1.0, 2.4212457953764286e-31],
#  ['true',
#   'positive',
#   0.9819562965458613,
#   0.00902185172707427,
#   0.9909781482729355],
#  ['false',
#   'positive',
#   0.999999892362208,
#   5.3818899261442964e-08,
#   0.9999999461811072],
#  ['true',
#   'negative',
#   0.9541040210234406,
#   0.9770520105116968,
#   0.022947989488256108],
#  ['true', 'negative', 1.0, 1.0, 7.35090552131735e-22],
#  ['false', 'negative', 1.0, 1.0, 2.216376903851147e-18],
#  ['true',
#   'negative',
#   0.9999936600912454,
#   0.9999968300455969,
#   3.169954351538696e-06],
#  ['true',
#   'negative',
#   0.9999681667011625,
#   0.9999840833505927,
#   1.5916649430209457e-05],
#  ['false',
#   'negative',
#   0.9999970173787978,
#   0.999998508689405,
#   1.4913106072822348e-06],
#  ['false',
#   'negative',
#   0.45313417153282576,
#   0.7265670857664229,
#   0.27343291423359717],
#  ['true', 'negative', 0.658413045981713, 0.829206522990857, 0.1707934770091439],
#  ['true',
#   'negative',
#   0.9864830539286897,
#   0.9932415269643934,
#   0.006758473035703629],
#  ['true',
#   'positive',
#   0.9645872007190365,
#   0.017706399640476454,
#   0.982293600359513],
#  ['true',
#   'positive',
#   0.9997776921521452,
#   0.00011115392391572786,
#   0.9998888460760609],
#  ['true',
#   'negative',
#   0.9999990149292564,
#   0.9999995074646298,
#   4.925353734552813e-07],
#  ['false',
#   'negative',
#   0.5711704776011134,
#   0.7855852388005254,
#   0.21441476119941208],
#  ['false',
#   'positive',
#   0.9999999998269615,
#   8.652283230255414e-11,
#   0.9999999999134843],
#  ['false',
#   'negative',
#   0.9999529503538874,
#   0.9999764751769354,
#   2.3524823048042267e-05],
#  ['false',
#   'negative',
#   0.9999949100372344,
#   0.9999974550186137,
#   2.544981379342739e-06],
#  ['false',
#   'negative',
#   0.5417914324769811,
#   0.7708957162385187,
#   0.22910428376153755]]

# %%
print("Fnal Model")

pipe.fit(X_train,y_train)


y_pred_fromtest2=pipe.predict(X_test2)
cr = classification_report(y_test2, y_pred_fromtest2)
cm = confusion_matrix(y_test2, y_pred_fromtest2)
accuracy = accuracy_score(y_pred_fromtest2, y_test2)
acc_test2.append(accuracy)
print("prediction from test data, model ke-",iterasi)
print(cr)
print("\nConfusion Matrix : \n",cm)
print("Accuracy :" , accuracy)
print("__________________________________________________________________________________________________")



len(X_train)
# Out:
# Fnal Model
# prediction from test data, model ke- 18
#               precision    recall  f1-score   support
#
#     negative       0.72      0.83      0.77      2463
#     positive       0.80      0.69      0.74      2537
#
#    micro avg       0.76      0.76      0.76      5000
#    macro avg       0.76      0.76      0.76      5000
# weighted avg       0.76      0.76      0.76      5000
#
#
# Confusion Matrix :
#  [[2041  422]
#  [ 796 1741]]
# Accuracy : 0.7564
# __________________________________________________________________________________________________
# 8044

# %%
plt.plot(acc_train)
plt.ylabel('Accuracy from Train data')
plt.show()

plt.plot(acc_test)
plt.ylabel('Accuracy from test data')
plt.show()

plt.plot(acc_test2)
plt.ylabel('Accuracy from test data 2')
plt.show()

# %%
len(X_train)
# Out:
# 8044
